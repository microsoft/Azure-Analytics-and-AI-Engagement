# %% [markdown]
# #### Run the cell below to install the required packages for Copilot

# %%
#Run this cell to install the required packages for Copilot
# %load_ext dscopilot_installer
# %activate_dscopilot
# Out:
# StatementMeta(, edc6b461-12a9-4983-9747-fccd1bea3720, 3, Finished, Available, Finished)

# %% [markdown]
# ### Getting Started with Copilot for Data Science notebook

# %% [markdown]
# ##### **Ways to Use Copilot**
#
# There are **four ways** to interact with Copilot:
#
# - A **Chat Panel** allows you to chat back and forth with Copilot. You can ask for code snippets and answers to questions. This is the same panel that you see throughout the rest of Fabric, meaning that you can also ask questions about your entire workspace.
#
# - **Copilot on Notebook Cells** allows you to prompt Copilot from the top of each of your notebook cells to generate code in code cells or Markdown in Markdown cell.
#
# - **iPython “magics” commands** allows you to ask Copilot questions or for code using simple magic commands in notebook cells. %%code will generate code in a cell much like Copilot on Notebook Cells, but %%chat in code cells allows you to ask questions and get a text response in the cell output
#
# - **Ask Help from Copilot** that simplify tedious tasks using AI, such as fixing code errors and adding code comments

# %% [markdown]
# ##### Feature 1: Chat Panel
#
# **Question:** Please load the "fact_churn" table from the lakehouseSilver_3zr5uti Lakehouse Explorer into a Spark DataFrame. Then convert that into pandas dataframe as df

# %%
#### ATTENTION: AI-generated code can include errors or operations you didn't intend. Review the code in this cell carefully before running it.

# Load the fact_churn table into a Spark DataFrame
spark_df = spark.read.table("fact_churn")

# Limit the number of rows to read (optional, adjust the limit as necessary)
max_rows_to_read = 1000
spark_df = spark_df.limit(max_rows_to_read)
# Out:
# StatementMeta(, edc6b461-12a9-4983-9747-fccd1bea3720, 4, Finished, Available, Finished)

# %% [markdown]
# ##### Feature 2: Copilot on Notebook Cells

# %% [markdown]
# ######  2.1 : Data Wrangler
#
# **Question:** Create a Data Wrangling function for df with the non-null values in the TotalAmount, dropping CustomerID and converting TotalAmount, UnitPrice into float and tenure to integer values. Then apply the function into df to create wrangled dataframe df

# %%
#### ATTENTION: AI-generated code can include errors or operations you didn't intend. Review the code in this cell carefully before running it.

from pyspark.sql.functions import col

# Define a data wrangling function for df
def data_wrangling(df):
    # Keep only the non-null values in the TotalAmount column
    df = df.filter(col('TotalAmount').isNotNull())
    # Drop the CustomerID column as it is not relevant for analysis
    df = df.drop('CustomerID')
    # Convert the TotalAmount and UnitPrice columns to float type
    df = df.withColumn('TotalAmount', col('TotalAmount').cast('float'))
    df = df.withColumn('UnitPrice', col('UnitPrice').cast('float'))
    # Convert the tenure column to integer type
    df = df.withColumn('Tenure_Month', col('Tenure_Month').cast('int'))
    # Return the wrangled DataFrame
    return df

# Apply the data wrangling function to df and assign it to a new variable
df = data_wrangling(df)

# %%
df.printSchema
# Out:
# StatementMeta(, edc6b461-12a9-4983-9747-fccd1bea3720, -1, Cancelled, , Cancelled)

# %% [markdown]
# ##### Feature 3: iPython “magics” commands

# %%
# %%chat
# Create a Seaborn scatter plot with tenure, TotalAmount, and Churn, DO NOT Create a new column that indicates whether a customer has churned or not
# Out:
# StatementMeta(, edc6b461-12a9-4983-9747-fccd1bea3720, -1, Cancelled, , Cancelled)

# %%
#### ATTENTION: AI-generated code can include errors or operations you didn't intend. Review the code in this cell carefully before running it.

import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of the visualization
sns.set(style="darkgrid")

# Create the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=pandas_df, x='Tenure_Month', y='TotalAmount', hue='Churn', palette='viridis')

plt.title('Scatter Plot of Tenure vs TotalAmount by Churn')
plt.xlabel('Tenure (Months)')
plt.ylabel('Total Amount')
plt.show()
# Out:
# StatementMeta(, edc6b461-12a9-4983-9747-fccd1bea3720, -1, Cancelled, , Cancelled)

# %%
# %%code
# Create a Seaborn scatter plot with tenure, TotalAmount, and Churn, DO NOT Create a new column that indicates whether a customer has churned or not
# Out:
# StatementMeta(, edc6b461-12a9-4983-9747-fccd1bea3720, -1, Cancelled, , Cancelled)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Read the necessary columns from the table
spark_df = spark.read.table("fact_customerchurndata_report").select("tenure_month", "TotalAmount", "Churn")

# Limit the rows to read for efficiency
max_rows_to_read = 1000
spark_df = spark_df.limit(max_rows_to_read)

# Convert the PySpark DataFrame to a Pandas DataFrame
pandas_df = spark_df.toPandas()

# Set the style of the visualization
sns.set(style="darkgrid")

# Create the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=pandas_df, x='tenure_month', y='TotalAmount', hue='Churn', palette='viridis')

plt.title('Scatter Plot of Tenure vs TotalAmount by Churn')
plt.xlabel('Tenure (Months)')
plt.ylabel('Total Amount')
plt.show()
# Out:
# StatementMeta(, edc6b461-12a9-4983-9747-fccd1bea3720, -1, Cancelled, , Cancelled)

# %%
#### ATTENTION: AI-generated code can include errors or operations you didn't intend. Review the code in this cell carefully before running it.

import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of the visualization
sns.set(style="darkgrid")

# Create the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=pandas_df, x='Tenure_Month', y='TotalAmount', hue='Churn', palette='viridis')

plt.title('Scatter Plot of Tenure vs TotalAmount by Churn')
plt.xlabel('Tenure (Months)')
plt.ylabel('Total Amount')
plt.show()
# Out:
# StatementMeta(, edc6b461-12a9-4983-9747-fccd1bea3720, -1, Cancelled, , Cancelled)

# %%
#### ATTENTION: AI-generated code can include errors or operations you didn't intend. Review the code in this cell carefully before running it.

# Import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt

# Create a scatter plot with Tenure_Month, TotalAmount, and Churn
sns.scatterplot(x='Tenure_Month', y='TotalAmount', hue='Churn', data=df_pandas)

# Add labels and title
plt.xlabel('Tenure (months)')
plt.ylabel('Total Amount ($)')
plt.title('Customer Churn by Tenure and Total Amount')

# Show the plot
plt.show()
# Out:
# StatementMeta(, edc6b461-12a9-4983-9747-fccd1bea3720, -1, Cancelled, , Cancelled)

# %% [markdown]
# ##### Feature 4: Ask Help from Copilot

# %%
from sklearn.model_selection import train_test_split

# Convert Spark DataFrame to Pandas DataFrame and split into features and target
pandas_df = df.toPandas()  # Convert once to avoid multiple conversions
X = pandas_df.drop(columns=["Churn"])
y = pandas_df["Churn"]

# Split the data into training and testing sets with reproducibility
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Print the shapes of the resulting datasets to verify the split
print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")

# %% [markdown]
# ###
