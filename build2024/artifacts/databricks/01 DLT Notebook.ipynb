# %%
# Install Dependency
# %pip install mlflow  # Package for managing and tracking machine learning experiments
# %pip install dlt  # Package for data lineage tracking
# %pip install databricks-automl-runtime  # Package for running AutoML experiments in Databricks
# %pip install holidays  # Package for working with holidays and business days
# %pip install numpy  # Package for numerical computing
# %pip install cloudpickle  # Package for serializing Python objects
# %pip install autocorrect  # Package for spelling correction
# %pip install better_profanity  # Package for detecting and filtering profanity
# %pip install geopy  # Package for geocoding and reverse geocoding
# %pip install category-encoders  # Package for encoding categorical variables
# %pip install xgboost==1.5.2  # Package for gradient boosting
# %pip install TextBlob  # Package for text processing and sentiment analysis
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting mlflow
#   Using cached mlflow-2.12.1-py3-none-any.whl (20.2 MB)
# Requirement already satisfied: pandas<3 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (1.4.4)
# Requirement already satisfied: scikit-learn<2 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (1.1.1)
# Collecting sqlparse<1,>=0.4.0
#   Using cached sqlparse-0.5.0-py3-none-any.whl (43 kB)
# Requirement already satisfied: click<9,>=7.0 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (8.0.4)
# Collecting graphene<4
#   Downloading graphene-3.3-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /usr/lib/python3/dist-packages (from mlflow) (4.6.4)
# Requirement already satisfied: packaging<25 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (21.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (2.28.1)
# Collecting markdown<4,>=3.3
#   Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Requirement already satisfied: pytz<2025 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (2022.1)
# Collecting Flask<4
#   Using cached flask-3.0.3-py3-none-any.whl (101 kB)
# Requirement already satisfied: Jinja2<4,>=2.11 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (2.11.3)
# Collecting cloudpickle<4
#   Using cached cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Collecting querystring-parser<2
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: scipy<2 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (1.9.1)
# Collecting pyyaml<7,>=5.1
#   Using cached PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (8.0.0)
# Collecting alembic!=1.10.0,<2
#   Using cached alembic-1.13.1-py3-none-any.whl (233 kB)
# Requirement already satisfied: entrypoints<1 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (0.4)
# Requirement already satisfied: matplotlib<4 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (3.5.2)
# Collecting gunicorn<22
#   Using cached gunicorn-21.2.0-py3-none-any.whl (80 kB)
# Collecting docker<8,>=4.0.0
#   Using cached docker-7.0.0-py3-none-any.whl (147 kB)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (3.19.4)
# Requirement already satisfied: numpy<2 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (1.21.5)
# Collecting sqlalchemy<3,>=1.4.0
#   Using cached SQLAlchemy-2.0.29-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Collecting gitpython<4,>=3.1.9
#   Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Requirement already satisfied: typing-extensions>=4 in /databricks/python3/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (4.3.0)
# Collecting Mako
#   Using cached Mako-1.3.3-py3-none-any.whl (78 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /databricks/python3/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow) (1.26.11)
# Collecting itsdangerous>=2.1.2
#   Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting blinker>=1.6.2
#   Downloading blinker-1.8.1-py3-none-any.whl (9.5 kB)
# Collecting Werkzeug>=3.0.0
#   Using cached werkzeug-3.0.2-py3-none-any.whl (226 kB)
# Collecting click<9,>=7.0
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting Jinja2<4,>=2.11
#   Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Collecting graphql-relay<3.3,>=3.1
#   Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Collecting aniso8601<10,>=8
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.5 MB/s eta 0:00:00
# Collecting graphql-core<3.3,>=3.1
#   Downloading graphql_core-3.2.3-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /databricks/python3/lib/python3.10/site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /databricks/python3/lib/python3.10/site-packages (from matplotlib<4->mlflow) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.10/site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.10/site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /databricks/python3/lib/python3.10/site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow) (3.3)
# Requirement already satisfied: joblib>=1.0.0 in /databricks/python3/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Collecting typing-extensions>=4
#   Using cached typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Collecting greenlet!=0.4.17
#   Using cached greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Installing collected packages: aniso8601, typing-extensions, sqlparse, smmap, querystring-parser, pyyaml, MarkupSafe, markdown, itsdangerous, greenlet, graphql-core, cloudpickle, click, blinker, Werkzeug, sqlalchemy, Mako, Jinja2, gunicorn, graphql-relay, gitdb, docker, graphene, gitpython, Flask, alembic, mlflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.3.0
#     Not uninstalling typing-extensions at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede
#     Can't uninstall 'typing_extensions'. No files were found to uninstall.
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Not uninstalling markupsafe at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
#   Attempting uninstall: click
#     Found existing installation: click 8.0.4
#     Not uninstalling click at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede
#     Can't uninstall 'click'. No files were found to uninstall.
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.4
#     Not uninstalling blinker at /usr/lib/python3/dist-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede
#     Can't uninstall 'blinker'. No files were found to uninstall.
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Not uninstalling jinja2 at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede
#     Can't uninstall 'Jinja2'. No files were found to uninstall.
# Successfully installed Flask-3.0.3 Jinja2-3.1.3 Mako-1.3.3 MarkupSafe-2.1.5 Werkzeug-3.0.2 alembic-1.13.1 aniso8601-9.0.1 blinker-1.8.1 click-8.1.7 cloudpickle-3.0.0 docker-7.0.0 gitdb-4.0.11 gitpython-3.1.43 graphene-3.3 graphql-core-3.2.3 graphql-relay-3.2.0 greenlet-3.0.3 gunicorn-21.2.0 itsdangerous-2.2.0 markdown-3.6 mlflow-2.12.1 pyyaml-6.0.1 querystring-parser-1.2.4 smmap-5.0.1 sqlalchemy-2.0.29 sqlparse-0.5.0 typing-extensions-4.11.0
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting dlt
#   Downloading dlt-0.4.9-py3-none-any.whl (632 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.7/632.7 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: gitpython>=3.1.29 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede/lib/python3.10/site-packages (from dlt) (3.1.43)
# Requirement already satisfied: tenacity>=8.0.2 in /databricks/python3/lib/python3.10/site-packages (from dlt) (8.1.0)
# Collecting orjson<=3.9.10,>=3.6.7
#   Downloading orjson-3.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 7.1 MB/s eta 0:00:00
# Collecting tzdata>=2022.1
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 9.2 MB/s eta 0:00:00
# Collecting astunparse>=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting makefun>=1.15.0
#   Downloading makefun-1.15.2-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: packaging>=21.1 in /databricks/python3/lib/python3.10/site-packages (from dlt) (21.3)
# Collecting requirements-parser>=0.5.0
#   Downloading requirements_parser-0.9.0-py3-none-any.whl (14 kB)
# Collecting humanize>=4.4.0
#   Downloading humanize-4.9.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 8.9 MB/s eta 0:00:00
# Collecting pendulum>=2.1.2
#   Downloading pendulum-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 11.8 MB/s eta 0:00:00
# Collecting pathvalidate>=2.5.2
#   Downloading pathvalidate-3.2.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests>=2.26.0 in /databricks/python3/lib/python3.10/site-packages (from dlt) (2.28.1)
# Collecting pytz>=2022.6
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 12.7 MB/s eta 0:00:00
# Collecting tomlkit>=0.11.3
#   Downloading tomlkit-0.12.4-py3-none-any.whl (37 kB)
# Collecting hexbytes>=0.2.2
#   Downloading hexbytes-1.2.0-py3-none-any.whl (5.9 kB)
# Collecting semver>=2.13.0
#   Downloading semver-3.0.2-py3-none-any.whl (17 kB)
# Collecting setuptools>=65.6.0
#   Downloading setuptools-69.5.1-py3-none-any.whl (894 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 894.6/894.6 kB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.4.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede/lib/python3.10/site-packages (from dlt) (6.0.1)
# Requirement already satisfied: click>=7.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede/lib/python3.10/site-packages (from dlt) (8.1.7)
# Collecting giturlparse>=0.10.0
#   Downloading giturlparse-0.12.0-py2.py3-none-any.whl (15 kB)
# Collecting black==23.9.1
#   Downloading black-23.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede/lib/python3.10/site-packages (from dlt) (4.11.0)
# Collecting fsspec>=2022.4.0
#   Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 19.7 MB/s eta 0:00:00
# Collecting simplejson>=3.17.5
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 17.2 MB/s eta 0:00:00
# Collecting jsonpath-ng>=1.5.3
#   Downloading jsonpath_ng-1.6.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: pathspec>=0.9.0 in /databricks/python3/lib/python3.10/site-packages (from black==23.9.1->dlt) (0.9.0)
# Requirement already satisfied: platformdirs>=2 in /databricks/python3/lib/python3.10/site-packages (from black==23.9.1->dlt) (2.5.2)
# Collecting packaging>=21.1
#   Downloading packaging-24.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: tomli>=1.1.0 in /databricks/python3/lib/python3.10/site-packages (from black==23.9.1->dlt) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /databricks/python3/lib/python3.10/site-packages (from black==23.9.1->dlt) (0.4.3)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/lib/python3/dist-packages (from astunparse>=1.6.3->dlt) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /databricks/python3/lib/python3.10/site-packages (from astunparse>=1.6.3->dlt) (0.37.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede/lib/python3.10/site-packages (from gitpython>=3.1.29->dlt) (4.0.11)
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.4 MB/s eta 0:00:00
# Collecting time-machine>=2.6.0
#   Downloading time_machine-2.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34 kB)
# Requirement already satisfied: python-dateutil>=2.6 in /databricks/python3/lib/python3.10/site-packages (from pendulum>=2.1.2->dlt) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.26.0->dlt) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.26.0->dlt) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.26.0->dlt) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.26.0->dlt) (1.26.11)
# Collecting types-setuptools>=69.1.0
#   Downloading types_setuptools-69.5.0.20240423-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: smmap<6,>=3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt) (5.0.1)
# Installing collected packages: pytz, ply, makefun, tzdata, types-setuptools, tomlkit, simplejson, setuptools, semver, pathvalidate, packaging, orjson, jsonpath-ng, humanize, hexbytes, giturlparse, fsspec, astunparse, time-machine, requirements-parser, black, pendulum, dlt
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Not uninstalling pytz at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede
#     Can't uninstall 'pytz'. No files were found to uninstall.
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 63.4.1
#     Not uninstalling setuptools at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede
#     Can't uninstall 'setuptools'. No files were found to uninstall.
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Not uninstalling packaging at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede
#     Can't uninstall 'packaging'. No files were found to uninstall.
#   Attempting uninstall: black
#     Found existing installation: black 22.6.0
#     Not uninstalling black at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede
#     Can't uninstall 'black'. No files were found to uninstall.
# Successfully installed astunparse-1.6.3 black-23.9.1 dlt-0.4.9 fsspec-2024.3.1 giturlparse-0.12.0 hexbytes-1.2.0 humanize-4.9.0 jsonpath-ng-1.6.1 makefun-1.15.2 orjson-3.9.10 packaging-24.0 pathvalidate-3.2.0 pendulum-3.0.0 ply-3.11 pytz-2024.1 requirements-parser-0.9.0 semver-3.0.2 setuptools-69.5.1 simplejson-3.19.2 time-machine-2.14.1 tomlkit-0.12.4 types-setuptools-69.5.0.20240423 tzdata-2024.1
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting databricks-automl-runtime
#   Downloading databricks_automl_runtime-0.2.21-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: databricks-automl-runtime
# Successfully installed databricks-automl-runtime-0.2.21
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting holidays
#   Downloading holidays-0.47-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /databricks/python3/lib/python3.10/site-packages (from holidays) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil->holidays) (1.16.0)
# Installing collected packages: holidays
# Successfully installed holidays-0.47
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.10/site-packages (1.21.5)
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: cloudpickle in /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede/lib/python3.10/site-packages (3.0.0)
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.8/622.8 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py): started
#   Building wheel for autocorrect (setup.py): finished with status 'done'
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622364 sha256=69010ed75d9e9cf10cfb4bde130cdfa4281975d1a177b0e5c0769a52528ec50c
#   Stored in directory: /root/.cache/pip/wheels/b5/7b/6d/b76b29ce11ff8e2521c8c7dd0e5bfee4fb1789d76193124343
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting better_profanity
#   Downloading better_profanity-0.7.0-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: better_profanity
# Successfully installed better_profanity-0.7.0
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 3.0 MB/s eta 0:00:00
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting category-encoders
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.5 in /databricks/python3/lib/python3.10/site-packages (from category-encoders) (1.4.4)
# Requirement already satisfied: patsy>=0.5.1 in /databricks/python3/lib/python3.10/site-packages (from category-encoders) (0.5.2)
# Requirement already satisfied: scipy>=1.0.0 in /databricks/python3/lib/python3.10/site-packages (from category-encoders) (1.9.1)
# Requirement already satisfied: numpy>=1.14.0 in /databricks/python3/lib/python3.10/site-packages (from category-encoders) (1.21.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /databricks/python3/lib/python3.10/site-packages (from category-encoders) (1.1.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /databricks/python3/lib/python3.10/site-packages (from category-encoders) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.10/site-packages (from pandas>=1.0.5->category-encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede/lib/python3.10/site-packages (from pandas>=1.0.5->category-encoders) (2024.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.1->category-encoders) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.10/site-packages (from scikit-learn>=0.20.0->category-encoders) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in /databricks/python3/lib/python3.10/site-packages (from scikit-learn>=0.20.0->category-encoders) (1.2.0)
# Requirement already satisfied: packaging>=21.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede/lib/python3.10/site-packages (from statsmodels>=0.9.0->category-encoders) (24.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.6.3
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting xgboost==1.5.2
#   Downloading xgboost-1.5.2-py3-none-manylinux2014_x86_64.whl (173.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.6/173.6 MB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.10/site-packages (from xgboost==1.5.2) (1.21.5)
# Requirement already satisfied: scipy in /databricks/python3/lib/python3.10/site-packages (from xgboost==1.5.2) (1.9.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.5.2
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting TextBlob
#   Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.3/626.3 kB 6.2 MB/s eta 0:00:00
# Collecting nltk>=3.8
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.9 MB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 7.2 MB/s eta 0:00:00
# Collecting regex>=2021.8.3
#   Downloading regex-2024.4.28-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (774 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.1/774.1 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: click in /local_disk0/.ephemeral_nfs/envs/pythonEnv-446a1bf7-df97-434c-89be-b911d5981ede/lib/python3.10/site-packages (from nltk>=3.8->TextBlob) (8.1.7)
# Requirement already satisfied: joblib in /databricks/python3/lib/python3.10/site-packages (from nltk>=3.8->TextBlob) (1.2.0)
# Installing collected packages: tqdm, regex, nltk, TextBlob
# Successfully installed TextBlob-0.18.0.post0 nltk-3.8.1 regex-2024.4.28 tqdm-4.66.2
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# #Campaign Analytics<br/>
#
# 1. **Usecase               :** Performing Campaign analytics on static campaign data coming from OneLake Bronze Layer.<br/>
# 2. **Notebook Summary      :** This notebook is a part of campaign analytics application which perform `campaign analytics using various pyspark capability`.<br/>
# 3. **Notebook Description  :** Performing Campaign Analytics on OneLake Bronze Layer Files.
#
#
# ###Feature List
# 1. Data Profiling
# 2. Total Revenue, Total Revenue Target & Profit
# 3. Campaign Run by Per Week
# 4. Total Profit by Country Per Week
# 5. Top Loss-Making Campaign
#
# The bronze data received for processing is already curated. So, we will derive gold tables from bronze tables.

# %% [markdown]
# ### Import Libraries

# %%
from pyspark.sql.functions import sum as _sum
from pyspark.sql.functions import mean as _mean
from pyspark.sql.functions import max as _max
from pyspark.sql.functions import min as _min
import pyspark.sql.functions as func
import pyspark.sql.functions as F
from pyspark.sql.functions import *
import dlt 
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType, DateType
import random
import string

# %% [markdown]
# ###Define the Schema for the input file

# %%
campaignSchema = StructType([    
    StructField("Region",StringType(),True),
    StructField("Country",StringType(),True),
    StructField("ProductCategory",StringType(),True),
    StructField("Campaign_ID",IntegerType(),True),    
    StructField("Campaign_Name",StringType(),True),
    StructField("Qualification",StringType(),True),
    StructField("Qualification_Number",StringType(),True),
    StructField("Response_Status",StringType(),True),
    StructField("Responses",FloatType(),True),
    StructField("Cost",FloatType(),True),
    StructField("Revenue",FloatType(),True),
    StructField("ROI",FloatType(),True),
    StructField("Lead_Generation",StringType(),True),
    StructField("Revenue_Target",FloatType(),True),
    StructField("Campaign_Tactic",StringType(),True),
    StructField("Customer_Segment",StringType(),True),
    StructField("Status",StringType(),True),
    StructField("Profit",FloatType(),True),
    StructField("Marketing_Cost",FloatType(),True),
    StructField("CampaignID",IntegerType(),True),
    StructField("CampDate",DateType(),True), 
    StructField("SORTED_ID",IntegerType(),True)])

# %% [markdown]
# ### Load the Campaign Dataset from OneLake Bronze Layer

# %%
# Bronze Table Setup
@dlt.table(comment="Raw data")
def bronze_campaign_data():
#   return (spark.table("campaign.campaign_source"))
  return (spark.read.format("csv").option("header",True).schema(campaignSchema).load("/Volumes/litware_unity_catalog/rag/documents_store/MktData/CampaignData.csv"))
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>bronze_campaign_data</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Region</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Country</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>ProductCategory</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Campaign_ID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Campaign_Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Qualification</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Qualification_Number</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Response_Status</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Responses</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>Cost</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>Revenue</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>ROI</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>Lead_Generation</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Revenue_Target</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>Campaign_Tactic</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Customer_Segment</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Status</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Profit</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>Marketing_Cost</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>CampaignID</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>CampDate</td>
#    <td>date</td>
# </tr>
#
# <tr>
#    <td>SORTED_ID</td>
#    <td>int</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=156618935127502#joblist/pipelines/create?initialSource=%2FShared%2FAnalytics%20with%20ADB1%2F03%20DLT%20Notebook&redirectNotebookId=248099371844316">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %% [markdown]
# ### Total Revenue, Total Revenue Target & Profit

# %%
# Gold Table Setup
@dlt.table(comment="Aggregated data")
def gold_country_wise_revenue():
    df = spark.table("LIVE.bronze_campaign_data").groupBy("Country","Region").agg(_sum("Revenue").alias("Total_Revenue"), _sum("Revenue_Target").alias("Total_Revenue_Target"),_sum("Profit").alias("Total_Profit"),_max("Cost").alias("Max_Cost"),_min("Cost").alias("Min_Cost"))
    df = df.withColumn("Total_Revenue", func.round(df["Total_Revenue"],2)).withColumn("Total_Revenue_Target", func.round(df["Total_Revenue_Target"], 2)).withColumn("Total_Profit", func.round(df["Total_Profit"], 2))
    return df
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_country_wise_revenue</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Country</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Region</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Total_Revenue</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Total_Revenue_Target</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Total_Profit</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>Max_Cost</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>Min_Cost</td>
#    <td>float</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=156618935127502#joblist/pipelines/create?initialSource=%2FShared%2FAnalytics%20with%20ADB1%2F03%20DLT%20Notebook&redirectNotebookId=248099371844316">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %% [markdown]
# ### Top Loss-Making Campaign

# %%
# Gold Table Setup
@dlt.table(comment="Aggregated data")
def gold_Top_Loss_Making_Campaign():
    loss = spark.table("LIVE.bronze_campaign_data").select("Campaign_Name","Profit").filter(F.col("Profit") < 0)
    loss = loss.withColumn("Loss_Count", F.when((F.col('Profit') < 0 ) , F.lit(1)).otherwise(F.lit(0)))
#     loss = loss.groupBy('Campaign_Name').sum('Loss_Count')
    return loss
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_Top_Loss_Making_Campaign</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>Campaign_Name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Profit</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>Loss_Count</td>
#    <td>int</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=156618935127502#joblist/pipelines/create?initialSource=%2FShared%2FAnalytics%20with%20ADB1%2F03%20DLT%20Notebook&redirectNotebookId=248099371844316">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %% [markdown]
# #  Retail Sales Data Preparation using Spark

# %% [markdown]
# Preparing retail data for training a regression model to predict total sales revenue of a product from a store using the following features:
# - Brand (The brand of the product)
# - Quantity (Quantity of product purchased)
# - Advert (Whether the product had an advertisement or not)
# - Price (How much the product costs)

# %% [markdown]
# ## Importing Libraries

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import percent_rank
from pyspark.sql import Window
from io import BytesIO
from copy import deepcopy
from datetime import datetime
from dateutil import parser
import logging
from pyspark.sql.types import *

# %% [markdown]
# ## Defining the schema for the data

# %%
Dataschema = StructType([
    StructField("ID", StringType()),
    StructField("WeekStarting", DateType()),
    StructField("Store", IntegerType()),
    StructField("Brand", StringType()),
    StructField("Quantity", IntegerType()),
    StructField("Advert", IntegerType()),
    StructField("Price", FloatType()),
    StructField("Revenue", FloatType())
])

# %% [markdown]
# ## Load the data from the source and perform the transformations

# %%
@dlt.table(comment="Raw data")    
def bronze_SalesTrans():
  return (spark.read.csv('/Volumes/litware_unity_catalog/rag/documents_store/MktData/SalesTransData.txt',schema=Dataschema))
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>bronze_SalesTrans</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>WeekStarting</td>
#    <td>date</td>
# </tr>
#
# <tr>
#    <td>Store</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Brand</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Quantity</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Advert</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Price</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>Revenue</td>
#    <td>float</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=156618935127502#joblist/pipelines/create?initialSource=%2FShared%2FAnalytics%20with%20ADB1%2F03%20DLT%20Notebook&redirectNotebookId=248099371844316">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(comment="Silver data")
def silver_SalesTrans_data():
    pydf = spark.table('LIVE.bronze_SalesTrans').withColumn("rank", percent_rank().over(Window.partitionBy().orderBy("WeekStarting")))
    return pydf
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>silver_rank_data</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>WeekStarting</td>
#    <td>date</td>
# </tr>
#
# <tr>
#    <td>Store</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Brand</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Quantity</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Advert</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Price</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>Revenue</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>rank</td>
#    <td>double</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=156618935127502#joblist/pipelines/create?initialSource=%2FShared%2FAnalytics%20with%20ADB1%2F03%20DLT%20Notebook&redirectNotebookId=248099371844316">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(comment="Silver data")
def gold_SalesTrans_toprank():
    train = spark.table('LIVE.silver_SalesTrans_data').where("rank <= .8").drop("rank")
    return train
    
@dlt.table(comment="Silver data")
def gold_SalesTrans_lowerrank():
    test = spark.table('LIVE.silver_SalesTrans_data').where("rank > .8").drop("rank")
    return test
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_test</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>WeekStarting</td>
#    <td>date</td>
# </tr>
#
# <tr>
#    <td>Store</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Brand</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Quantity</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Advert</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Price</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>Revenue</td>
#    <td>float</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=156618935127502#joblist/pipelines/create?initialSource=%2FShared%2FAnalytics%20with%20ADB1%2F03%20DLT%20Notebook&redirectNotebookId=248099371844316">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %% [markdown]
# #  Customer Churn Data Preparation using Spark

# %% [markdown]
# ## Load the data from the source and perform the transformations

# %%
@dlt.table(comment="Raw data") 
def bronze_CustomerChurnTrans():
  return (spark.read.csv('/Volumes/litware_unity_catalog/rag/documents_store/MktData/CustomerChurnData.csv',  header=True))
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>bronze_CustomerChurnTrans</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>CustomerID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Gender</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>SeniorCitizen</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Partner</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Dependents</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>tenure</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Discount</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OutletSize</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OnlineDelivery</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>OrderStatus</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>CustomerSupport</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Brand</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>StoreContract</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>PaperlessBilling</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>PaymentMethod</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>UnitPrice</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>TotalAmount</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Churn</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=156618935127502#joblist/pipelines/create?initialSource=%2FShared%2FAnalytics%20with%20ADB1%2F03%20DLT%20Notebook&redirectNotebookId=248099371844316">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
@dlt.table(comment="Silver data")
def silver_CustomerChurn_data():
    pydf = spark.table('LIVE.bronze_CustomerChurnTrans')
    return pydf
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>silver_CustomerChurn_data</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>ID</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>WeekStarting</td>
#    <td>date</td>
# </tr>
#
# <tr>
#    <td>Store</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Brand</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>Quantity</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Advert</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>Price</td>
#    <td>float</td>
# </tr>
#
# <tr>
#    <td>Revenue</td>
#    <td>float</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=156618935127502#joblist/pipelines/create?initialSource=%2FShared%2FAnalytics%20with%20ADB1%2F03%20DLT%20Notebook&redirectNotebookId=248099371844316">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %% [markdown]
# The result after running DLT pipeline would look similar to the following screenshot.
#
# ![](https://stmsftbuild2024.blob.core.windows.net/dltimage/task-2.2.7.png)
