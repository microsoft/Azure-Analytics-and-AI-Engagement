# %% [markdown]
# ## *DISCLAIMER*
# <p style="font-size:16px; color:#117d30;">
#  By accessing this code, you acknowledge the code is made available for presentation and demonstration purposes only and that the code: (1) is not subject to SOC 1 and SOC 2 compliance audits; (2) is not designed or intended to be a substitute for the professional advice, diagnosis, treatment, or judgment of a certified financial services professional; (3) is not designed, intended or made available as a medical device; and (4) is not designed or intended to be a substitute for professional medical advice, diagnosis, treatment or judgement. Do not use this code to replace, substitute, or provide professional financial advice or judgment, or to replace, substitute or provide medical advice, diagnosis, treatment or judgement. You are solely responsible for ensuring the regulatory, legal, and/or contractual compliance of any use of the code, including obtaining any authorizations or consents, and any solution you choose to build that incorporates this code in whole or in part.
# </p>

# %% [markdown]
# # Face Mask Safety Compliance in a Retail Store - Face Mask Detection
# <h3><span style="color: #117d30;"> Using Azure Custom Vision Cognitive Services</span></h3>

# %% [markdown]
# ![](https://stretaildemodev.blob.core.windows.net/notebookimages/image.jpg)

# %% [markdown]
# ## Legal Notices
#
# This presentation, demonstration, and demonstration model are for informational purposes only. Microsoft makes no warranties, express or implied, in this presentation demonstration, and demonstration model. Nothing in this presentation, demonstration, or demonstration model modifies any of the terms and conditions of Microsoft’s written and signed agreements. This is not an offer and applicable terms and the information provided is subject to revision and may be changed at any time by Microsoft.
#
# This presentation, demonstration, and/or demonstration model do not give you or your organization any license to any patents, trademarks, copyrights, or other intellectual property covering the subject matter in this presentation, demonstration, and demonstration model.
#
# The information contained in this presentation, demonstration and demonstration model represent the current view of Microsoft on the issues discussed as of the date of presentation and/or demonstration, and the duration of your access to the demonstration model. Because Microsoft must respond to changing market conditions, it should not be interpreted to be a commitment on the part of Microsoft, and Microsoft cannot guarantee the accuracy of any information presented after the date of presentation and/or demonstration and for the duration of your access to the demonstration model.
#
# No Microsoft technology, nor any of its component technologies, including the demonstration model, is intended or made available: (1) as a medical device; (2) for the diagnosis of disease or other conditions, or in the cure, mitigation, treatment or prevention of a disease or other conditions; or (3) as a substitute for the professional clinical advice, opinion, or judgment of a treating healthcare professional. Partners or customers are responsible for ensuring the regulatory compliance of any solution they build using Microsoft technologies.
#
# © 2020 Microsoft Corporation. All rights reserved

# %% [markdown]
# ## Scenario Overview
#
# **Azure Custom Vision** is a cognitive service which helps in building and deploying object detection and image classification models.
#
# This notebook provides an end-to-end demo on how to use the Azure Cognitive Services Custom Vision API to build and deploy an object detection model to detect **compliance related to face masks**.
#
# In this scenario we will see how the model provides the count of all workers and the count of workers wearing face masks. All incidents of PPE non-compliance, where any worker is not wearing a face mask, are marked as Non-Compliant.
#
#
#
# + This demo uses real-world video footage from a hospital setting
# + This raw video is stored in an ADLSGen2 storage container
# + In this notebook, we process this raw video using Azure Custom Vision Cognitive Services model and get a processed video complete with:
#
#     * Moving Bounding boxes and moving tags for workers
#     * Moving Bounding boxes and moving tags for face masks
#     * Count of workers and face masks
#     * Frame-wise annotation of Compliance and Non-Compliance

# %% [markdown]
# ## Setting-Up:
#
# + Defining the storage, file path and file name for **raw input** video
# + Defining the storage, file path and file name for **processed output** video

# %% [markdown]
# ## Installing OpenCV and importing other python libraries
#
# OpenCV is one of the most popular computer vision libraries for image and video processing. In this notebook, we will install python binding for  OpenCV.
#
# We will also import other libraries like  **matplotlib**,  **numpy**, **pandas**, etc. that are required at different stages in this notebook for manipulating and processing images.

# %%
import GlobalVariables

# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()

from azure.storage.blob import BlobClient

blob = BlobClient.from_connection_string(conn_str=GlobalVariables.STORAGE_ACCOUNT_CONNECTION_STRING, 
                                         container_name=GlobalVariables.CONTAINER_NAME, 
                                         blob_name='retail-store.mp4')

with open("data/retail-store.mp4", "wb") as my_blob:
    blob_data = blob.download_blob()
    blob_data.readinto(my_blob)
# Out:
# Requirement already satisfied: nest_asyncio in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.5.4)
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated

# %%
import os


# for converting the frames into bytes
import cv2 

# and for processing arrays   
import numpy as np

# for encoding and decoding Custom Vision predictions 
import json

# for converting the Custom Vision predictions to dataframe   
import pandas as pd

# import async packages
import asyncio
import aiohttp

# for file name pattern matching   
import fnmatch  

# for displaying images from the processes output video   
import matplotlib.pyplot as plt

# importing other required libraries
import random
import textwrap
import datetime 
from PIL import Image
import time

# %% [markdown]
# ## Making API call to Custom Vision Cognitive Service
#
# Now we will define connections details for making the API call to the Custom Vision Service

# %%
# web service end-point for the Custom Vision model    
# we will process video frames (which are images)   
POST_URL = GlobalVariables.FACE_MASK_END_POINT

# providing prediction key
HEADERS = {'Prediction-Key': GlobalVariables.FACE_MASK_PREDICTION_KEY,"Content-Type":"application/json"}

# number of API calls per pool of request   
MAX_CONNECTIONS = 100 

# initializing the height and width for frames in the video 
WIDTH = 0
HEIGHT = 0

# %% [markdown]
# ## Functions to converting raw input video to processed video

# %% [markdown]
# ### function: getFrames
#
# This function takes a  video as input and returns list of frames

# %%
# returns frame array of video
def getFrames(path):
    images = []
    byteImages = []
    vidObj = cv2.VideoCapture(path)
    count = 0
    success = 1
    while success:
        success, image = vidObj.read()
        if success:
            images.append(image)
            count += 1
    global HEIGHT, WIDTH
    HEIGHT, WIDTH, lay = images[0].shape
    return images

# %% [markdown]
# ### function: convertCVImagesToByteImages
#
# This function takes a list of frames as input and returns list of Byte arrays

# %%
# Returns ByteImages for POST request params
def convertCVImagesToByteImages(frames):
    toReturnByteImages = []
    for frame in frames:
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        is_success, im_buf_arr = cv2.imencode(".jpg", image)
        if is_success:
            byte_im = im_buf_arr.tobytes()
            toReturnByteImages.append(byte_im)
    return toReturnByteImages

# %% [markdown]
# ### function: makeRequests
#
# This function takes a list of ByteImages and a prediction threshold as inputs and returns a list of bounding box co-ordinates, a list of tag data, and a list of Custom Vision service responses in data frames. The function calls some other functions that are also defined in this cell.

# %%
# making async requests call
async def fetch(session, url, data,i):
    print("Request #" + str(i) + " Sent")
    async with session.post(url,headers=HEADERS, data=data) as response:
        resp = await response.text()
        print("Request #"+ str(i) + " Complete")
        return resp

# Setting up for batch requests
async def fetch_all(byteImages):
    conn = aiohttp.TCPConnector(limit=len(byteImages)+1)
    async with aiohttp.ClientSession(connector=conn) as session:
        tasks = []
        i = 0
        for image in byteImages:
            i = i+1
            # if i%20 == 0:
                # time.sleep(3)
            tasks.append( fetch(session, POST_URL, image, i) )

        responses = await asyncio.gather(*tasks, return_exceptions=True)
        return responses


# defining a function to convert raw JSON to a dataframe
def getDFfromResponse(response,threshold):
    resp = json.loads(response)
    pred= resp['predictions']
    pred_df=pd.DataFrame(pred)
    resp_df = pred_df[pred_df['probability'] > float(threshold)]
    return resp_df

# defining a function to converting the bounding box dataframe to a list 
def boundingBoxListFromDF(df):
    cood_list = df['boundingBox'].tolist()
    return cood_list

# defining a function for adjusting the size of bounding box 
def fitAccordingToSize(coods):
    print("Multiplying by " + str(WIDTH) + " , " + str(HEIGHT))
    for i in range(len(coods)):
        coods[i]['left']=coods[i]['left']*WIDTH
        coods[i]['top']=coods[i]['top']*HEIGHT
        coods[i]['width']=coods[i]['width']*WIDTH
        coods[i]['height']=coods[i]['height']*WIDTH
    return coods


#==================== function: makeRequests ====================#  
# defining a function to get bounding box coordinates and tags
# makes calls to other functions defined above 
def makeRequests(byteImages,threshold):
    tagsData = []
    bound_box_cood = []
    responseJSON =  []

    # futures = [...]
    loop = asyncio.get_event_loop()
    check = loop.run_until_complete(fetch_all(byteImages))
    # check = asyncio.run()
    # check = await fetch_all(byteImages)
    for i,response in enumerate(check):
        df = getDFfromResponse(response, threshold)
        listBx = boundingBoxListFromDF(df)
        listBx = fitAccordingToSize(listBx)
        taglist = df['tagName'].tolist()
        tagsData.append(taglist)
        bound_box_cood.append(listBx)
        responseJSON.append(df)


    return bound_box_cood,tagsData, responseJSON

# %% [markdown]
# ### function: isCompliant
#
# This function takes a list of tags for a given frame as input and returns a Boolean after matching the count of worker tags and face mask tags.

# %%
# defining a function to check compliance or non-compliance for a frame
def isCompliant(tags):
    return (len(list(filter(lambda x: x == 'mask', tags))) >= len(list(filter(lambda x: x == 'person',tags))))

# %% [markdown]
# ### function: printCNC
#
# This function checks if a frame is compliant or non-compliant and then adds the appropriate labels.

# %%
# Print for Compliance Label
def PrintCompliance(frames,i,font,lineType):
    frames[i] = cv2.rectangle(
        frames[i], (WIDTH - 300, 0), (WIDTH, 50), (0, 128, 0), -1)
    frames[i] = cv2.putText(frames[i], "COMPLIANT",
                            (WIDTH - 220, 33),
                            font,
                            1,
                            (255, 255, 255), 2,
                            lineType)

# Print for Non-Compliance Label
def PrintNonCompliance(frames, i, font, lineType):
    frames[i] = cv2.rectangle(
        frames[i], (WIDTH - 300, 0), (WIDTH, 50), (0, 0, 128), -1)
    frames[i] = cv2.putText(frames[i], "NON-COMPLIANT",
                            (WIDTH - 275, 34),
                            font,
                            1,
                            (255, 255, 255), 2,
                            lineType)  

#==================== function: printCNC ====================#  
#Check for compliance or non-compliance label
def printCNC(which, frames, i, font, lineType):
    if which:
        PrintCompliance(frames, i, font, lineType)
    else:
        PrintNonCompliance(frames, i, font, lineType)

# %% [markdown]
# ### function: SaveVideo
#
# We are using this function to convert a list of frames into a video.

# %%
# defining a function to convert a list of frames into a video 
def SaveVideo(frames, output_file_name):
    img_array = []
    for img in frames:
        height, width, layers = img.shape
        size = (width,height)
        img_array.append(img)

    out = cv2.VideoWriter(output_file_name,cv2.VideoWriter_fourcc(*'MP4V'), 15, size)
    for i in range(len(img_array)):
        out.write(img_array[i])
    out.release()

# %% [markdown]
# ## function: ConvertVideo
#
# This function combines raw frames into a processed video. It relies on several other functions that have been defined above.

# %%
# defining a function to convert raw input video to processed video with tags and stats
def ConvertVideo(video_path, output_file_name, threshold, nframes):
    frames = getFrames(video_path) # this converts the input video into frames   
    
    if nframes != 'all':
        frames = frames[:int(nframes)]
    
    byteImages = convertCVImagesToByteImages(frames) # this converts frames into list of byte images
    
    coodsData,tagsData, responses = makeRequests(byteImages, threshold) # this returns lists of coordinate data, tag data, responses in dataframe   
    
    font                   = cv2.FONT_HERSHEY_SIMPLEX
    bottomLeftCornerOfText = (50,50)
    fontScale              = 0.5
    fontColor              = (255,255,255)
    lineType               = 1
    frames_stats = []

    for i,coods_single in enumerate(coodsData):
        dflist = responses[i].drop('boundingBox', axis=1)
        print(dflist['tagId'])
        dflist['tagId'] = (dflist['tagId'].to_string())[-10:]
        dflist.reset_index(drop=True, inplace=True)
        d = dflist.to_dict(orient='records')
        jo = json.dumps(d)
        width = 600
        height = 1080
        blank_image=np.zeros((height, width, 3), np.uint8)
        n_masks = len([x for x in tagsData[i] if x == 'mask'])
        n_people = len([x for x in tagsData[i] if x == 'Person'])
        color = (0, 0, 0)
        blank_image[:height//2] = color
        blank_image[height//2:] = (0, 0, 0)
        blank_image = cv2.putText(blank_image, "STATISTICS" ,(230, 70),font, 1,(66, 245,173),2 ,lineType)
        blank_image = cv2.rectangle(blank_image, (80,150), (width-60, 220), (66, 245,173), 2)
        blank_image = cv2.rectangle(blank_image, (80, 260), (width-60, 330), (66, 245, 173), 2)
        blank_image = cv2.putText(blank_image, "NO OF PEOPLE:         "+ str(n_people),(90+20, 195),font, 0.9,(66, 245,173),2 ,lineType)
        blank_image = cv2.putText(blank_image, "NO OF MASKS:          "+ str(n_masks),(90+20, 305),font, 0.9,(66, 245,173),2 ,lineType)
        relative_start = height//2 + - 150
        x, y0 = (50, relative_start)
        text = dflist.to_string()
        thickness = 10
        text_size, _ = cv2.getTextSize(text, font, fontScale, thickness)
        line_height = text_size[1] + 20
    
        if len(text) != 0:
            for k, line in enumerate(text.split("\n")):
                y = y0 + k * line_height
                relative_start = y
                if k == 0:
                    ctext = '      Probability      Id          Tag'
                    blank_image = cv2.putText(blank_image, ctext, (x, y), font, 0.8, (66, 245,173),2, lineType)
                else:
                    blank_image = cv2.putText(blank_image, line, (x, y), font, 0.8, (66, 245,173),2, lineType)
   
        wrapped_text = textwrap.wrap(jo, width=50)
        x, y0 = (10, relative_start)
    
        if relative_start > 700:
            y = relative_start
        else:
            y = 700
    
        for p, line in enumerate(wrapped_text):
            print(line)
            y = y + 30
            blank_image =  cv2.putText(blank_image, line, (10, y), font, 0.7, (66, 245,173),2, lineType)

        frames_stats.append(blank_image)
        last = None

        if len(tagsData[i]) == 0:
            pass

        elif not isCompliant(tagsData[i]): # this checks for compliance for the frame
            if i % 5 == 0:
                PrintNonCompliance(frames, i, font, lineType) # this prints non-compliant labels   
                last = 0
            else:
                if last == None:
                    PrintNonCompliance(frames, i, font, lineType) 
                    last = 0
                else:
                    printCNC(last, frames, font, lineType) # this checks for compliance before applying compliance labels

        else:
            if i % 5 == 0:
                PrintCompliance(frames, i, font, lineType) # this prints compliant labels 
                last = 1
            else:
                if last == None:
                    PrintCompliance(frames, i, font, lineType)
                    last = 1
                else:
                    printCNC(last, frames, font, lineType)

        for j,single in enumerate(coods_single):
            # this puts the tab on top of the detected item
            frames[i] = cv2.rectangle(frames[i],  (int(single['left']) - 3, int(single['top']) - 30), ((int(single['left']) + 100, int(single['top']) - 3)), (66, 245,173), -1)
            frames[i] = cv2.putText(frames[i],tagsData[i][j],
                (int(single['left'] + 2), int(single['top']) + - 8),
                font,
                0.9,
                (0,0,0),2,
                lineType)

            # this creates the bounding box
            frames[i] = cv2.rectangle(frames[i],  (int(single['left']), int(single['top'])), (int(single['left'])+int(single['width']), int(single['top'])+int(single['height'])), (66, 245,173) ,3)
       
        frames[i] = np.concatenate((frames[i], frames_stats[i]), axis=1)

    SaveVideo(frames, output_file_name) # this converts frames into a video
    stats_path = output_file_name.replace('Output', 'Stats')
    SaveVideo(frames_stats, stats_path)

# %% [markdown]
# ## Video conversion and ADLSGen2 storage
#
# We wil make functions calls to convert the raw input video to processed video and store the processed video to ADLSGen2 storage.

# %%
# creating Output and Stats directories for saving processed videos 
if not os.path.isdir("Output"):
   os.mkdir("Output")
if not os.path.isdir("Stats"):
   os.mkdir("Stats")

# %%
# converting raw input video to processed video complete with tags and stats
threshold=0.3
ConvertVideo("data/retail-store.mp4", "Output/output_video.mp4",threshold,nframes='all')
# Out:
# Request #1 Sent
# Request #2 Sent
# Request #3 Sent
# Request #4 Sent
# Request #402 Sent
# Request #38 Sent
# Request #39 Sent
# Request #111 Sent
# Request #321 Sent
# Request #320 Sent
# Request #104 Sent
# Request #123 Sent
# Request #290 Sent
# Request #110 Sent
# Request #296 Sent
# Request #308 Sent
# Request #112 Sent
# Request #315 Sent
# Request #124 Sent
# Request #317 Sent
# Request #230 Sent
# Request #307 Sent
# Request #120 Sent
# Request #316 Sent
# Request #330 Sent
# Request #122 Sent
# Request #331 Sent
# Request #125 Sent
# Request #314 Sent
# Request #332 Sent
# Request #313 Sent
# Request #228 Sent
# Request #327 Sent
# Request #229 Sent
# Request #329 Sent
# Request #101 Sent
# Request #227 Sent
# Request #323 Sent
# Request #103 Sent
# Request #326 Sent
# Request #102 Sent
# Request #319 Sent
# Request #299 Sent
# Request #298 Sent
# Request #297 Sent
# Request #117 Sent
# Request #318 Sent
# Request #116 Sent
# Request #300 Sent
# Request #113 Sent
# Request #292 Sent
# Request #127 Sent
# Request #291 Sent
# Request #115 Sent
# Request #328 Sent
# Request #118 Sent
# Request #226 Sent
# Request #312 Sent
# Request #121 Sent
# Request #311 Sent
# Request #114 Sent
# Request #119 Sent
# Request #322 Sent
# Request #305 Sent
# Request #306 Sent
# Request #324 Sent
# Request #325 Sent
# Request #294 Sent
# Request #309 Sent
# Request #304 Sent
# Request #303 Sent
# Request #295 Sent
# Request #310 Sent
# Request #100 Sent
# Request #302 Sent
# Request #98 Sent
# Request #126 Sent
# Request #293 Sent
# Request #99 Sent
# Request #301 Sent
# Request #86 Sent
# Request #92 Sent
# Request #83 Sent
# Request #96 Sent
# Request #88 Sent
# Request #91 Sent
# Request #87 Sent
# Request #89 Sent
# Request #94 Sent
# Request #84 Sent
# Request #90 Sent
# Request #93 Sent
# Request #85 Sent
# Request #97 Sent
# Request #95 Sent
# Request #491 Sent
# Request #238 Sent
# Request #242 Sent
# Request #249 Sent
# Request #233 Sent
# Request #260 Sent
# Request #257 Sent
# Request #263 Sent
# Request #248 Sent
# Request #237 Sent
# Request #244 Sent
# Request #232 Sent
# Request #109 Sent
# Request #243 Sent
# Request #246 Sent
# Request #259 Sent
# Request #235 Sent
# Request #255 Sent
# Request #107 Sent
# Request #253 Sent
# Request #236 Sent
# Request #234 Sent
# Request #239 Sent
# Request #252 Sent
# Request #231 Sent
# Request #240 Sent
# Request #258 Sent
# Request #251 Sent
# Request #256 Sent
# Request #106 Sent
# Request #245 Sent
# Request #264 Sent
# Request #262 Sent
# Request #261 Sent
# Request #105 Sent
# Request #254 Sent
# Request #241 Sent
# Request #108 Sent
# Request #247 Sent
# Request #250 Sent
# Request #14 Sent
# Request #57 Sent
# Request #150 Sent
# Request #27 Sent
# Request #59 Sent
# Request #136 Sent
# Request #10 Sent
# Request #40 Sent
# Request #138 Sent
# Request #167 Sent
# Request #8 Sent
# Request #51 Sent
# Request #149 Sent
# Request #25 Sent
# Request #47 Sent
# Request #151 Sent
# Request #171 Sent
# Request #31 Sent
# Request #58 Sent
# Request #147 Sent
# Request #9 Sent
# Request #79 Sent
# Request #148 Sent
# Request #26 Sent
# Request #68 Sent
# Request #137 Sent
# Request #29 Sent
# Request #72 Sent
# Request #132 Sent
# Request #37 Sent
# Request #69 Sent
# Request #145 Sent
# Request #168 Sent
# Request #44 Sent
# Request #139 Sent
# Request #34 Sent
# Request #77 Sent
# Request #169 Sent
# Request #41 Sent
# Request #144 Sent
# Request #35 Sent
# Request #63 Sent
# Request #146 Sent
# Request #70 Sent
# Request #142 Sent
# Request #21 Sent
# Request #64 Sent
# Request #143 Sent
# Request #56 Sent
# Request #133 Sent
# Request #30 Sent
# Request #54 Sent
# Request #13 Sent
# Request #65 Sent
# Request #50 Sent
# Request #81 Sent
# Request #73 Sent
# Request #52 Sent
# Request #19 Sent
# Request #7 Sent
# Request #80 Sent
# Request #135 Sent
# Request #17 Sent
# Request #49 Sent
# Request #22 Sent
# Request #75 Sent
# Request #53 Sent
# Request #5 Sent
# Request #67 Sent
# Request #170 Sent
# Request #28 Sent
# Request #42 Sent
# Request #61 Sent
# Request #12 Sent
# Request #82 Sent
# Request #16 Sent
# Request #71 Sent
# Request #36 Sent
# Request #74 Sent
# Request #166 Sent
# Request #6 Sent
# Request #43 Sent
# Request #66 Sent
# Request #15 Sent
# Request #60 Sent
# Request #32 Sent
# Request #48 Sent
# Request #18 Sent
# Request #76 Sent
# Request #134 Sent
# Request #11 Sent
# Request #46 Sent
# Request #23 Sent
# Request #33 Sent
# Request #45 Sent
# Request #24 Sent
# Request #62 Sent
# Request #55 Sent
# Request #20 Sent
# Request #78 Sent
# Request #140 Sent
# Request #141 Sent
# Request #157 Sent
# Request #283 Sent
# Request #359 Sent
# Request #429 Sent
# Request #485 Sent
# Request #343 Sent
# Request #449 Sent
# Request #478 Sent
# Request #370 Sent
# Request #427 Sent
# Request #497 Sent
# Request #284 Sent
# Request #360 Sent
# Request #436 Sent
# Request #477 Sent
# Request #285 Sent
# Request #361 Sent
# Request #441 Sent
# Request #487 Sent
# Request #338 Sent
# Request #426 Sent
# Request #493 Sent
# Request #337 Sent
# Request #495 Sent
# Request #277 Sent
# Request #346 Sent
# Request #423 Sent
# Request #472 Sent
# Request #288 Sent
# Request #347 Sent
# Request #430 Sent
# Request #287 Sent
# Request #348 Sent
# Request #454 Sent
# Request #483 Sent
# Request #344 Sent
# Request #452 Sent
# Request #476 Sent
# Request #286 Sent
# Request #364 Sent
# Request #466 Sent
# Request #342 Sent
# Request #463 Sent
# Request #492 Sent
# Request #345 Sent
# Request #438 Sent
# Request #161 Sent
# Request #365 Sent
# Request #447 Sent
# Request #490 Sent
# Request #205 Sent
# Request #366 Sent
# Request #453 Sent
# Request #473 Sent
# Request #156 Sent
# Request #207 Sent
# Request #279 Sent
# Request #349 Sent
# Request #431 Sent
# Request #484 Sent
# Request #278 Sent
# Request #357 Sent
# Request #462 Sent
# Request #468 Sent
# Request #153 Sent
# Request #280 Sent
# Request #356 Sent
# Request #437 Sent
# Request #486 Sent
# Request #208 Sent
# Request #265 Sent
# Request #336 Sent
# Request #439 Sent
# Request #488 Sent
# Request #281 Sent
# Request #355 Sent
# Request #455 Sent
# Request #471 Sent
# Request #165 Sent
# Request #206 Sent
# Request #358 Sent
# Request #432 Sent
# Request #474 Sent
# Request #152 Sent
# Request #350 Sent
# Request #433 Sent
# Request #481 Sent
# Request #282 Sent
# Request #363 Sent
# Request #422 Sent
# Request #362 Sent
# Request #445 Sent
# Request #496 Sent
# Request #160 Sent
# Request #375 Sent
# Request #457 Sent
# Request #276 Sent
# Request #373 Sent
# Request #459 Sent
# Request #494 Sent
# Request #353 Sent
# Request #465 Sent
# Request #480 Sent
# Request #213 Sent
# Request #272 Sent
# Request #377 Sent
# Request #442 Sent
# Request #341 Sent
# Request #444 Sent
# Request #470 Sent
# Request #269 Sent
# Request #374 Sent
# Request #456 Sent
# Request #467 Sent
# Request #376 Sent
# Request #451 Sent
# Request #498 Sent
# Request #163 Sent
# Request #352 Sent
# Request #440 Sent
# Request #212 Sent
# Request #270 Sent
# Request #354 Sent
# Request #443 Sent
# Request #211 Sent
# Request #275 Sent
# Request #339 Sent
# Request #460 Sent
# Request #274 Sent
# Request #371 Sent
# Request #461 Sent
# Request #475 Sent
# Request #273 Sent
# Request #369 Sent
# Request #446 Sent
# Request #489 Sent
# Request #154 Sent
# Request #209 Sent
# Request #289 Sent
# Request #435 Sent
# Request #368 Sent
# Request #434 Sent
# Request #162 Sent
# Request #210 Sent
# Request #266 Sent
# Request #340 Sent
# Request #424 Sent
# Request #155 Sent
# Request #271 Sent
# Request #351 Sent
# Request #428 Sent
# Request #479 Sent
# Request #268 Sent
# Request #367 Sent
# Request #450 Sent
# Request #164 Sent
# Request #267 Sent
# Request #372 Sent
# Request #464 Sent
# Request #469 Sent
# Request #158 Sent
# Request #335 Sent
# Request #425 Sent
# Request #159 Sent
# Request #333 Sent
# Request #448 Sent
# Request #334 Sent
# Request #458 Sent
# Request #482 Sent
# Request #174 Sent
# Request #407 Sent
# Request #175 Sent
# Request #222 Sent
# Request #406 Sent
# Request #198 Sent
# Request #220 Sent
# Request #403 Sent
# Request #179 Sent
# Request #219 Sent
# Request #404 Sent
# Request #195 Sent
# Request #221 Sent
# Request #420 Sent
# Request #200 Sent
# Request #417 Sent
# Request #181 Sent
# Request #409 Sent
# Request #196 Sent
# Request #418 Sent
# Request #188 Sent
# Request #378 Sent
# Request #187 Sent
# Request #410 Sent
# Request #177 Sent
# Request #400 Sent
# Request #128 Sent
# Request #182 Sent
# Request #399 Sent
# Request #176 Sent
# Request #217 Sent
# Request #413 Sent
# Request #203 Sent
# Request #405 Sent
# Request #186 Sent
# Request #216 Sent
# Request #398 Sent
# Request #185 Sent
# Request #401 Sent
# Request #199 Sent
# Request #412 Sent
# Request #411 Sent
# Request #218 Sent
# Request #395 Sent
# Request #408 Sent
# Request #131 Sent
# Request #390 Sent
# Request #421 Sent
# Request #225 Sent
# Request #389 Sent
# Request #414 Sent
# Request #396 Sent
# Request #173 Sent
# Request #394 Sent
# Request #184 Sent
# Request #393 Sent
# Request #183 Sent
# Request #223 Sent
# Request #386 Sent
# Request #383 Sent
# Request #193 Sent
# Request #380 Sent
# Request #204 Sent
# Request #379 Sent
# Request #172 Sent
# Request #381 Sent
# Request #384 Sent
# Request #385 Sent
# Request #191 Sent
# Request #215 Sent
# Request #382 Sent
# Request #130 Sent
# Request #194 Sent
# Request #214 Sent
# Request #416 Sent
# Request #129 Sent
# Request #197 Sent
# Request #415 Sent
# Request #224 Sent
# Request #392 Sent
# Request #180 Sent
# Request #192 Sent
# Request #391 Sent
# Request #178 Sent
# Request #419 Sent
# Request #190 Sent
# Request #397 Sent
# Request #202 Sent
# Request #388 Sent
# Request #189 Sent
# Request #387 Sent
# Request #201 Sent
# Request #140 Complete
# Request #99 Complete
# Request #123 Complete
# Request #319 Complete
# Request #258 Complete
# Request #441 Complete
# Request #16 Complete
# Request #186 Complete
# Request #218 Complete
# Request #125 Complete
# Request #365 Complete
# Request #443 Complete
# Request #84 Complete
# Request #25 Complete
# Request #31 Complete
# Request #233 Complete
# Request #318 Complete
# Request #342 Complete
# Request #322 Complete
# Request #23 Complete
# Request #122 Complete
# Request #90 Complete
# Request #11 Complete
# Request #72 Complete
# Request #240 Complete
# Request #321 Complete
# Request #454 Complete
# Request #30 Complete
# Request #247 Complete
# Request #100 Complete
# Request #2 Complete
# Request #126 Complete
# Request #196 Complete
# Request #255 Complete
# Request #456 Complete
# Request #57 Complete
# Request #276 Complete
# Request #274 Complete
# Request #154 Complete
# Request #119 Complete
# Request #471 Complete
# Request #236 Complete
# Request #423 Complete
# Request #108 Complete
# Request #26 Complete
# Request #139 Complete
# Request #110 Complete
# Request #425 Complete
# Request #112 Complete
# Request #447 Complete
# Request #221 Complete
# Request #316 Complete
# Request #200 Complete
# Request #473 Complete
# Request #421 Complete
# Request #89 Complete
# Request #40 Complete
# Request #438 Complete
# Request #310 Complete
# Request #21 Complete
# Request #74 Complete
# Request #301 Complete
# Request #105 Complete
# Request #169 Complete
# Request #60 Complete
# Request #210 Complete
# Request #187 Complete
# Request #353 Complete
# Request #326 Complete
# Request #188 Complete
# Request #135 Complete
# Request #216 Complete
# Request #414 Complete
# Request #349 Complete
# Request #62 Complete
# Request #184 Complete
# Request #192 Complete
# Request #363 Complete
# Request #77 Complete
# Request #159 Complete
# Request #202 Complete
# Request #275 Complete
# Request #351 Complete
# Request #430 Complete
# Request #146 Complete
# Request #299 Complete
# Request #298 Complete
# Request #121 Complete
# Request #450 Complete
# Request #415 Complete
# Request #329 Complete
# Request #130 Complete
# Request #37 Complete
# Request #228 Complete
# Request #264 Complete
# Request #333 Complete
# Request #403 Complete
# Request #323 Complete
# Request #133 Complete
# Request #371 Complete
# Request #330 Complete
# Request #81 Complete
# Request #219 Complete
# Request #204 Complete
# Request #352 Complete
# Request #197 Complete
# Request #263 Complete
# Request #101 Complete
# Request #478 Complete
# Request #266 Complete
# Request #13 Complete
# Request #71 Complete
# Request #283 Complete
# Request #177 Complete
# Request #251 Complete
# Request #291 Complete
# Request #312 Complete
# Request #305 Complete
# Request #277 Complete
# Request #390 Complete
# Request #490 Complete
# Request #82 Complete
# Request #350 Complete
# Request #289 Complete
# Request #419 Complete
# Request #19 Complete
# Request #75 Complete
# Request #243 Complete
# Request #41 Complete
# Request #448 Complete
# Request #245 Complete
# Request #248 Complete
# Request #491 Complete
# Request #466 Complete
# Request #484 Complete
# Request #234 Complete
# Request #453 Complete
# Request #429 Complete
# Request #18 Complete
# Request #3 Complete
# Request #178 Complete
# Request #97 Complete
# Request #195 Complete
# Request #238 Complete
# Request #205 Complete
# Request #20 Complete
# Request #348 Complete
# Request #215 Complete
# Request #261 Complete
# Request #161 Complete
# Request #294 Complete
# Request #78 Complete
# Request #385 Complete
# Request #33 Complete
# Request #246 Complete
# Request #487 Complete
# Request #128 Complete
# Request #260 Complete
# Request #297 Complete
# Request #463 Complete
# Request #46 Complete
# Request #170 Complete
# Request #477 Complete
# Request #307 Complete
# Request #250 Complete
# Request #302 Complete
# Request #208 Complete
# Request #176 Complete
# Request #134 Complete
# Request #189 Complete
# Request #435 Complete
# Request #142 Complete
# Request #158 Complete
# Request #114 Complete
# Request #9 Complete
# Request #409 Complete
# Request #404 Complete
# Request #386 Complete
# Request #336 Complete
# Request #220 Complete
# Request #416 Complete
# Request #43 Complete
# Request #402 Complete
# Request #225 Complete
# Request #387 Complete
# Request #287 Complete
# Request #399 Complete
# Request #111 Complete
# Request #34 Complete
# Request #311 Complete
# Request #496 Complete
# Request #115 Complete
# Request #279 Complete
# Request #229 Complete
# Request #10 Complete
# Request #480 Complete
# Request #257 Complete
# Request #461 Complete
# Request #32 Complete
# Request #309 Complete
# Request #230 Complete
# Request #7 Complete
# Request #455 Complete
# Request #109 Complete
# Request #427 Complete
# Request #68 Complete
# Request #468 Complete
# Request #459 Complete
# Request #475 Complete
# Request #281 Complete
# Request #388 Complete
# Request #167 Complete
# Request #47 Complete
# Request #35 Complete
# Request #479 Complete
# Request #436 Complete
# Request #141 Complete
# Request #151 Complete
# Request #53 Complete
# Request #127 Complete
# Request #288 Complete
# Request #327 Complete
# Request #28 Complete
# Request #452 Complete
# Request #36 Complete
# Request #306 Complete
# Request #44 Complete
# Request #59 Complete
# Request #242 Complete
# Request #70 Complete
# Request #65 Complete
# Request #262 Complete
# Request #224 Complete
# Request #152 Complete
# Request #239 Complete
# Request #211 Complete
# Request #285 Complete
# Request #56 Complete
# Request #485 Complete
# Request #244 Complete
# Request #481 Complete
# Request #449 Complete
# Request #271 Complete
# Request #280 Complete
# Request #314 Complete
# Request #227 Complete
# Request #424 Complete
# Request #358 Complete
# Request #214 Complete
# Request #433 Complete
# Request #317 Complete
# Request #6 Complete
# Request #87 Complete
# Request #355 Complete
# Request #347 Complete
# Request #362 Complete
# Request #194 Complete
# Request #206 Complete
# Request #91 Complete
# Request #54 Complete
# Request #174 Complete
# Request #14 Complete
# Request #69 Complete
# Request #76 Complete
# Request #345 Complete
# Request #38 Complete
# Request #474 Complete
# Request #201 Complete
# Request #61 Complete
# Request #469 Complete
# Request #58 Complete
# Request #400 Complete
# Request #50 Complete
# Request #293 Complete
# Request #15 Complete
# Request #410 Complete
# Request #492 Complete
# Request #106 Complete
# Request #493 Complete
# Request #364 Complete
# Request #320 Complete
# Request #138 Complete
# Request #411 Complete
# Request #413 Complete
# Request #331 Complete
# Request #292 Complete
# Request #131 Complete
# Request #207 Complete
# Request #107 Complete
# Request #357 Complete
# Request #235 Complete
# Request #143 Complete
# Request #129 Complete
# Request #137 Complete
# Request #442 Complete
# Request #42 Complete
# Request #94 Complete
# Request #444 Complete
# Request #428 Complete
# Request #374 Complete
# Request #63 Complete
# Request #379 Complete
# Request #495 Complete
# Request #426 Complete
# Request #272 Complete
# Request #303 Complete
# Request #117 Complete
# Request #420 Complete
# Request #249 Complete
# Request #256 Complete
# Request #445 Complete
# Request #393 Complete
# Request #259 Complete
# Request #92 Complete
# Request #217 Complete
# Request #498 Complete
# Request #368 Complete
# Request #39 Complete
# Request #48 Complete
# Request #66 Complete
# Request #80 Complete
# Request #8 Complete
# Request #346 Complete
# Request #470 Complete
# Request #398 Complete
# Request #308 Complete
# Request #439 Complete
# Request #432 Complete
# Request #232 Complete
# Request #296 Complete
# Request #422 Complete
# Request #1 Complete
# Request #367 Complete
# Request #373 Complete
# Request #29 Complete
# Request #378 Complete
# Request #389 Complete
# Request #341 Complete
# Request #166 Complete
# Request #116 Complete
# Request #203 Complete
# Request #408 Complete
# Request #4 Complete
# Request #51 Complete
# Request #5 Complete
# Request #315 Complete
# Request #52 Complete
# Request #384 Complete
# Request #136 Complete
# Request #332 Complete
# Request #73 Complete
# Request #190 Complete
# Request #334 Complete
# Request #185 Complete
# Request #198 Complete
# Request #85 Complete
# Request #120 Complete
# Request #340 Complete
# Request #237 Complete
# Request #17 Complete
# Request #252 Complete
# Request #162 Complete
# Request #222 Complete
# Request #472 Complete
# Request #213 Complete
# Request #270 Complete
# Request #49 Complete
# Request #381 Complete
# Request #118 Complete
# Request #95 Complete
# Request #376 Complete
# Request #290 Complete
# Request #380 Complete
# Request #157 Complete
# Request #226 Complete
# Request #295 Complete
# Request #494 Complete
# Request #284 Complete
# Request #79 Complete
# Request #268 Complete
# Request #360 Complete
# Request #55 Complete
# Request #370 Complete
# Request #144 Complete
# Request #96 Complete
# Request #278 Complete
# Request #431 Complete
# Request #418 Complete
# Request #103 Complete
# Request #482 Complete
# Request #83 Complete
# Request #181 Complete
# Request #179 Complete
# Request #375 Complete
# Request #325 Complete
# Request #304 Complete
# Request #102 Complete
# Request #359 Complete
# Request #22 Complete
# Request #396 Complete
# Request #172 Complete
# Request #434 Complete
# Request #391 Complete
# Request #397 Complete
# Request #464 Complete
# Request #462 Complete
# Request #489 Complete
# Request #395 Complete
# Request #451 Complete
# Request #354 Complete
# Request #282 Complete
# Request #437 Complete
# Request #193 Complete
# Request #212 Complete
# Request #372 Complete
# Request #171 Complete
# Request #104 Complete
# Request #273 Complete
# Request #180 Complete
# Request #417 Complete
# Request #209 Complete
# Request #497 Complete
# Request #164 Complete
# Request #124 Complete
# Request #343 Complete
# Request #394 Complete
# Request #324 Complete
# Request #344 Complete
# Request #361 Complete
# Request #401 Complete
# Request #382 Complete
# Request #392 Complete
# Request #86 Complete
# Request #163 Complete
# Request #458 Complete
# Request #147 Complete
# Request #286 Complete
# Request #356 Complete
# Request #300 Complete
# Request #377 Complete
# Request #338 Complete
# Request #369 Complete
# Request #153 Complete
# Request #339 Complete
# Request #199 Complete
# Request #150 Complete
# Request #183 Complete
# Request #446 Complete
# Request #383 Complete
# Request #412 Complete
# Request #476 Complete
# Request #148 Complete
# Request #149 Complete
# Request #168 Complete
# Request #406 Complete
# Request #265 Complete
# Request #165 Complete
# Request #113 Complete
# Request #156 Complete
# Request #241 Complete
# Request #98 Complete
# Request #337 Complete
# Request #335 Complete
# Request #175 Complete
# Request #173 Complete
# Request #267 Complete
# Request #231 Complete
# Request #155 Complete
# Request #465 Complete
# Request #405 Complete
# Request #45 Complete
# Request #366 Complete
# Request #67 Complete
# Request #328 Complete
# Request #182 Complete
# Request #467 Complete
# Request #483 Complete
# Request #132 Complete
# Request #486 Complete
# Request #269 Complete
# Request #27 Complete
# Request #12 Complete
# Request #407 Complete
# Request #223 Complete
# Request #88 Complete
# Request #160 Complete
# Request #64 Complete
# Request #191 Complete
# Request #457 Complete
# Request #313 Complete
# Request #460 Complete
# Request #24 Complete
# Request #253 Complete
# Request #145 Complete
# Request #488 Complete
# Request #93 Complete
# Request #440 Complete
# Request #254 Complete
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8944031, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.8782079,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.77394336, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.76841754,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.6871248, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 5    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8920313, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.87105906,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7820017, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.77530533,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.6864168, "tagId": "bca10cbc4b",
# "tagName": "mask"}, {"probability": 0.3045318,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8838577, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.87748706,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.76684284, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7613006,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.6819295, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 5    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8944568, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.8674722,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7837184, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7781276,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.67654777, "tagId": "bca10cbc4b",
# "tagName": "mask"}, {"probability": 0.3322319,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 5    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.90798056, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.87071097, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.78690994,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7737832, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.66331494,
# "tagId": "bca10cbc4b", "tagName": "mask"},
# {"probability": 0.36336857, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 5    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.9064843, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.87378967,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7719457, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7718697,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.6331984, "tagId": "bca10cbc4b",
# "tagName": "mask"}, {"probability": 0.40415803,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 5    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.90450037, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.86954975, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.77798396,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7566214, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.6108103,
# "tagId": "bca10cbc4b", "tagName": "mask"},
# {"probability": 0.35200664, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 5    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.91050744, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.8718328, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.78593504,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7815855, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.5808187,
# "tagId": "bca10cbc4b", "tagName": "mask"},
# {"probability": 0.32276145, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.90746534, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.8686199, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.78969485,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.77718556, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.5979914,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.9169105, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.8688649,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.79175836, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.77996045,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.6118036, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.9204508, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.86784256,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.79227334, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7897904,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.6035954, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.92257845, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.86585957, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.8138247,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.75250494, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.6091921,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 5    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.9173474, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.8695865,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.80262935, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7517518,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.61893165, "tagId": "bca10cbc4b",
# "tagName": "mask"}, {"probability": 0.32704076,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.91668767, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.8740054, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7970743,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.75598234, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.52202725,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.9185757, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.8791888,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7808421, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7548789,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.46230644, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.91494876, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.8857051, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.77506506,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7608835, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.45264307,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.9110468, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.88123953,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7784735, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7706916,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.4315273, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.9132016, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.8788585,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.77263325, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7673063,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.37217957, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.9116542, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.88195187,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7730092, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.76954013,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.34249747, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 5    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.911349, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.8870932,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.78599536, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.77856565,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.3332513, "tagId": "bca10cbc4b",
# "tagName": "mask"}, {"probability": 0.31712404,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 5    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 6    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.9140512, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.8874785,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.80282664, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7852463,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.37932384, "tagId": "bca10cbc4b",
# "tagName": "mask"}, {"probability": 0.3320545,
# "tagId": "bca10cbc4b", "tagName": "mask"},
# {"probability": 0.31297323, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 5    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.9120176, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.89026594,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.81354916, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7865444,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.39895958, "tagId": "bca10cbc4b",
# "tagName": "mask"}, {"probability": 0.36523223,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 5    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.9128759, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.8895603,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# ...
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8211164, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.70377135,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.6877717, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.49882817,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8349288, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.6934861,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.6805378, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.5209736,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.832034, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7294606,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.66615695, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.51524854,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8170697, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.72291464,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.6276944, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.48461232,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.82842726, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.72937495, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.72731763,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.53807336, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.83510876, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7313177, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7035966,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.54633623, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.83180106, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.73236454, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.6917747,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.53522193, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.83190906, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7249118, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.6387607,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.57938683, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8201026, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7281972,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7090534, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.55538756,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8283708, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.72740096,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.67915905, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.5687813,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8285339, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7436728,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7153901, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.56638044,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.81813186, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.73121285, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.69124734,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.55117035, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.83062464, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7122568, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7111051,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.5258771, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8281007, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7406241,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.67580116, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.53073025,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.83352256, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7409366, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.71865714,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.5523154, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.82618153, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7330921, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7254617,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.45937237, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.7961638, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.76268584,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.72852236, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.4907555,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.80316705, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.74979013, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.70730376,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.4889175, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.80793303, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.76912105, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7446499,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.5451945, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8076607, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7673048,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7407175, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.51260877,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# 4    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.81432587, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.77265215, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7426428,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.5394027, "tagId": "bca10cbc4b",
# "tagName": "mask"}, {"probability": 0.31057474,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8254474, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7708377,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.74684554, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.55264974,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8277618, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7631795,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.76190543, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.6169058,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.82583374, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.75745016, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7486146,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.61350477, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8361358, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.785243,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.76050586, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.5976262,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.83908844, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.78716314, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.73036814,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.57950187, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.85086024, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.77121496, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.73557246,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.6324649, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8471756, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7625498,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7338433, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.6722132,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8413398, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7618649,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.75486857, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.6765072,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.83897984, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.77138853, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.75275075,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.6283833, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.84749764, "tagId":
# "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.77041334, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.75814974,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.64493346, "tagId": "bca10cbc4b",
# "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8381363, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.7613579,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7557967, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.54787827,
# "tagId": "bca10cbc4b", "tagName": "mask"}]
# 0    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 1    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 2    22a743be-dc4f-49b2-bfec-cc316defd5f6
# 3    121cbdda-2918-4b04-9165-d5bca10cbc4b
# Name: tagId, dtype: object
# [{"probability": 0.8358442, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.75947154,
# "tagId": "bca10cbc4b", "tagName": "Person"},
# {"probability": 0.7546382, "tagId": "bca10cbc4b",
# "tagName": "Person"}, {"probability": 0.539466,
# "tagId": "bca10cbc4b", "tagName": "mask"}]

# %%
upload_blob = BlobClient.from_connection_string(conn_str=GlobalVariables.STORAGE_ACCOUNT_CONNECTION_STRING, 
                                         container_name=GlobalVariables.CONTAINER_NAME, 
                                         blob_name='output_video.mp4')

with open("Output/output_video.mp4", "rb") as data:
    upload_blob.upload_blob(data,overwrite=True)
# Out:
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated
# Tuple timeout setting is deprecated

# %% [markdown]
# ## Displaying frames from processed video

# %%
# saving processed video as images inside the frames directory
images = []
byteImages = []
vidObj = cv2.VideoCapture("Output/output_video.mp4")
count = 0
success = 1
currentDir = os.getcwd()
if not os.path.isdir("frames"):
   os.mkdir("frames")
while success:
      success, image = vidObj.read()
      if success:
          cv2.imwrite("frames/frame%d.jpg" % count, image) 
          count += 1

images_num=(len(fnmatch.filter(os.listdir(os.getcwd() + "/frames"), '*.jpg')))

# displaying images from frames directory
i=0
for i in range(images_num):
    if i%75==0:
      a = plt.imread("frames/frame%d.jpg" % i)
      plt.imshow(a)
      plt.show()
