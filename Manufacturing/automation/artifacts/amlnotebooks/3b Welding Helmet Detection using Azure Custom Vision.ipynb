# %% [markdown]
# ## Please don't run / don't click "Run all" the notebook:
#
# At the time of writing of this document, the current core limit is 200 cores per workspace and depending upon number of concurrent users, you may end up with core capacity being exceeded or maximum number of parallel jobs being exceeded error.

# %% [markdown]
# # PPE Safety Compliance in Manufacturing - Welding Helmet Detection
# <h3><span style="color: #117d30;"> Using Azure Custom Vision Congnitive Services</span></h3>

# %% [markdown]
# ## Scenario Overview
#
# **Azure Custom Vision** is a cognitive service which helps in building and deploying object detection and image classification models.
#
# This notebook provides an end-to-end demo on how to use the Azure Cognitive Services Custom Vision API to build and deploy an object detection model to detect **PPE compliance related to welding helmets**.
#
# In this scenario we will see how the model provides the count of all workers and the count of workers wearing welding helmets. All incidents of PPE non-compliance, where any worker is not wearing a welding helmet, are marked as Non-Compliant.
#
#
#
# + This demo uses real-world video footage from a manufacturing setting
# + This raw video is stored in an ADLSGen2 storage container
# + In this notebook, we process this raw video using Azure Custom Vision Cognitive Services model and get a processed video complete with:
#
#     * Moving Bounding boxes and moving tags for workers
#     * Moving Bounding boxes and moving tags for welding helmets
#     * Count of workers and welding helmets
#     * Frame-wise annotation of Compliance and Non-Compliance

# %% [markdown]
# ## Setting-Up:
#
# + Defining the storage, file path and file name for **raw input** video
# + Defining the storage, file path and file name for **processed output** video

# %%
## setting up the credentials for ADLS Gen2
import os
from azure.storage.blob import BlockBlobService

# Importing user defined config
import config

# setting up blob storage configs
STORAGE_ACCOUNT_NAME = config.STORAGE_ACCOUNT_NAME
STORAGE_ACCOUNT_ACCESS_KEY = config.STORAGE_ACCOUNT_ACCESS_KEY
STORAGE_CONTAINER_NAME = "ppecompliancedetection"

# defining the folders for raw input video and processed output video  
input_folder="WeldingHelmet/Input/"
output_folder="WeldingHelmet/Output/"

# getting the file name from the folder in blob folder
blob_service = BlockBlobService(STORAGE_ACCOUNT_NAME, STORAGE_ACCOUNT_ACCESS_KEY) 

# providing the filename from input folder
input_file="sample.mp4"
output_file="processed_sample.mp4"
blob_file=input_folder + input_file

# downloading the file from the blob storage
download_file_path = os.path.join(os.getcwd(), input_file)
blob_service.get_blob_to_path(STORAGE_CONTAINER_NAME, blob_file ,download_file_path)

# defining the input and output video paths 
input_video_path=download_file_path
output_video_path=os.path.join(os.getcwd(), "Output",output_file)

# %% [markdown]
# ## Installing OpenCV and importing other python libraries
#
# OpenCV is one of the most popular computer vision libraries for image and video processing. In this notebook, we will install python binding for  OpenCV.
#
# We will also import other libraries like  **matplotlib**,  **numpy**, **pandas**, etc. that are required at different stages in this notebook for manipulating and processing images.

# %%
import os

# installing and importing the OpenCV library 
# openCV will be used to grab frames from the video 
# and for converting the frames into arrays   

# !pip install opencv-python-headless
# !pip install grequests

import cv2 

# and for processing arrays   
import numpy as np

# for encoding and decoding Custom Vision predictions 
import json

# for converting the Custom Vision predictions to dataframes   
import pandas as pd

# making web service calls in batches
import grequests 

# for file name pattern matching   
import fnmatch  

# for displaying images from the processed output video   
import matplotlib.pyplot as plt

# importing other required libraries
import random
import textwrap
import datetime 
from PIL import Image
import time
# Out:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/grequests.py:22: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util (/anaconda/envs/azureml_py36/lib/python3.6/site-packages/urllib3/util/__init__.py)', 'urllib3.contrib.pyopenssl (/anaconda/envs/azureml_py36/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py)'].
#   curious_george.patch_all(thread=False, select=False)

# %% [markdown]
# ## Making API call to Custom Vision Cognitive Service
#
# Now we will define connections details for making the API call to the Custom Vision Service

# %%
# web service end-point for the Custom Vision model    
# we will process video frames (which are images)   
POST_URL = config.WELDING_HELMET_POST_URL
print(POST_URL)
# providing prediction key
HEADERS = config.WELDING_HELMET_HEADERS
print(HEADERS)

# number of API calls per pool of request   
MAX_CONNECTIONS = 100 

# initializing the height and width for frames in the video 
WIDTH = 0
HEIGHT = 0

# %% [markdown]
# ## Functions to convert raw input video to processed video

# %% [markdown]
# ### function: getFrames
#
# This function takes a  video as input and returns a list of frames

# %%
# returns an array of frames of the video
def getFrames(path):
    images = []
    byteImages = []
    vidObj = cv2.VideoCapture(path)
    count = 0
    success = 1
    while success:
        success, image = vidObj.read()
        if success:
            images.append(image)
            count += 1
    global HEIGHT, WIDTH
    HEIGHT, WIDTH, lay = images[0].shape
    return images

# %% [markdown]
# ### function: convertCVImagesToByteImages
#
# This function takes a list of frames as input and returns list of Byte arrays

# %%
# Returns ByteImages for POST request params
def convertCVImagesToByteImages(frames):
    toReturnByteImages = []
    for frame in frames:
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        is_success, im_buf_arr = cv2.imencode(".jpg", image)
        if is_success:
            byte_im = im_buf_arr.tobytes()
            toReturnByteImages.append(byte_im)
    return toReturnByteImages

# %% [markdown]
# ### function: makeRequests
#
# This function takes a list of ByteImages and a prediction threshold as inputs and returns a list of bounding box co-ordinates, a list of tag data, and a list of Custom Vision service responses in data frames. The function calls some other functions that are also defined in this cell.

# %%
# defining a function for making batch HTTP requests
def batchRequest(byteImages):
    results = []
    for x in range(0,len(byteImages)+1, MAX_CONNECTIONS):
        rs = (grequests.post(POST_URL,headers=HEADERS,data=u,stream=False) for u in byteImages[x:x+MAX_CONNECTIONS])
        time.sleep(0.2)
        results.extend(grequests.map(rs)) 
    response_list=[response.text for response in results]
    return response_list

# defining a function to convert raw JSON to a dataframe
def getDFfromResponse(response,threshold):
    resp = json.loads(response)
    pred= resp['predictions']
    pred_df=pd.DataFrame(pred)
    resp_df = pred_df[pred_df['probability'] > float(threshold)]
    return resp_df

# defining a function to convert the bounding box dataframe to a list 
def boundingBoxListFromDF(df):
    cood_list = df['boundingBox'].tolist()
    return cood_list

# defining a function for adjusting the size of the bounding box 
def fitAccordingToSize(coods):
    print("Multiplying by " + str(WIDTH) + " , " + str(HEIGHT))
    for i in range(len(coods)):
        coods[i]['left']=coods[i]['left']*WIDTH
        coods[i]['top']=coods[i]['top']*HEIGHT
        coods[i]['width']=coods[i]['width']*WIDTH
        coods[i]['height']=coods[i]['height']*WIDTH
    return coods


#==================== function: makeRequests ====================#  
# defining a function to get bounding box coordinates and tags
# makes calls to other functions defined above 
def makeRequests(byteImages,threshold):
    tagsData = []
    bound_box_cood = []
    responseJSON =  []
    response_array=batchRequest(byteImages)
    for i,response in enumerate(response_array):
        df = getDFfromResponse(response, threshold)
        listBx = boundingBoxListFromDF(df)
        listBx = fitAccordingToSize(listBx)
        taglist = df['tagName'].tolist()
        tagsData.append(taglist)
        bound_box_cood.append(listBx)
        responseJSON.append(df)
    return bound_box_cood,tagsData,responseJSON

# %% [markdown]
# ### function: isCompliant
#
# This function takes a list of tags for a given frame as input and returns a Boolean after matching the count of worker tags and welding helmet tags.

# %%
# defining a function to check compliance or non-compliance for a frame
def isCompliant(tags):
    return (len(list(filter(lambda x: x == 'welding_helmet', tags))) == len(list(filter(lambda x: x == 'worker',tags))))

# %% [markdown]
# ### function: printCNC
#
# This function checks if a frame is compliant or non-compliant and then adds the appropriate labels.

# %%
# Print Compliance Label
def PrintCompliance(frames,i,font,lineType):
    frames[i] = cv2.rectangle(
        frames[i], (WIDTH - 300, 0), (WIDTH, 50), (0, 128, 0), -1)
    frames[i] = cv2.putText(frames[i], "COMPLIANT",
                            (WIDTH - 220, 33),
                            font,
                            1,
                            (255, 255, 255), 2,
                            lineType)

# Print Non-Compliance Label
def PrintNonCompliance(frames, i, font, lineType):
    frames[i] = cv2.rectangle(
        frames[i], (WIDTH - 300, 0), (WIDTH, 50), (0, 0, 128), -1)
    frames[i] = cv2.putText(frames[i], "NON-COMPLIANT",
                            (WIDTH - 275, 34),
                            font,
                            1,
                            (255, 255, 255), 2,
                            lineType)  

#==================== function: printCNC ====================#  
# Check for compliance or non-compliance label
def printCNC(which, frames, i, font, lineType):
    if which:
        PrintCompliance(frames, i, font, lineType)
    else:
        PrintNonCompliance(frames, i, font, lineType)

# %% [markdown]
# ### function: SaveVideo
#
# We are using this function to convert a list of frames into a video.

# %%
# defining a function to convert a list of frames into a video 
def SaveVideo(frames, output_file_name):
    img_array = []
    for img in frames:
        height, width, layers = img.shape
        size = (width,height)
        img_array.append(img)

    out = cv2.VideoWriter(output_file_name,cv2.VideoWriter_fourcc(*'MP4V'), 15, size)
    for i in range(len(img_array)):
        out.write(img_array[i])
    out.release()

# %% [markdown]
# ## function: ConvertVideo
#
# This function combines raw frames into a processed video. It relies on several other functions that have been defined above.

# %%
# defining a function to convert raw input video to processed video with tags and stats
def ConvertVideo(video_path, output_file_name, threshold, nframes):
    frames = getFrames(video_path) # this converts the input video into frames

    if nframes != 'all':
        frames = frames[:int(nframes)]

    byteImages = convertCVImagesToByteImages(frames) # this converts frames into a list of byte images

    coodsData,tagsData, responses = makeRequests(byteImages, threshold) # this returns lists of bounding box coordinate data, tag data, responses in dataframe

    font                   = cv2.FONT_HERSHEY_SIMPLEX
    bottomLeftCornerOfText = (50,50)
    fontScale              = 0.5
    fontColor              = (255,255,255)
    lineType               = 1
    frames_stats = []

    for i,coods_single in enumerate(coodsData):
        dflist = responses[i].drop('boundingBox', axis=1)
        print(dflist['tagId'])
        dflist['tagId'] = (dflist['tagId'].to_string())[-10:]
        dflist.reset_index(drop=True, inplace=True)
        d = dflist.to_dict(orient='records')
        jo = json.dumps(d)



        width = 600
        height = 1080
        blank_image=np.zeros((height, width, 3), np.uint8)


        n_helmets = len([x for x in tagsData[i] if x == 'welding_helmet'])
        n_workers = len([x for x in tagsData[i] if x == 'worker'])

        color = (0, 0, 0)


        blank_image[:height//2] = color
        blank_image[height//2:] = (0, 0, 0)


        blank_image = cv2.putText(blank_image, "STATISTICS" ,(230, 70),font, 1,(66, 245,173),2 ,lineType)
        blank_image = cv2.rectangle(blank_image,  (80,150), (width-60, 220), (66, 245,173), 2)
        blank_image = cv2.rectangle(
            blank_image,  (80, 260), (width-60, 330), (66, 245, 173), 2)
        blank_image = cv2.putText(blank_image, "NO OF WORKERS:         "+ str(n_workers),(90+20, 195),font, 0.9,(66, 245,173),2 ,lineType)
        blank_image = cv2.putText(blank_image, "NO OF WELDING HELMETS: "+ str(n_helmets),(90+20, 305),font, 0.9,(66, 245,173),2 ,lineType)
       
        relative_start = height//2 + - 150
        x, y0 = (10, relative_start)

        text = dflist.to_string()
        thickness = 10
        text_size, _ = cv2.getTextSize(text, font, fontScale, thickness)
        line_height = text_size[1] + 20

        if len(text) != 0:
            for k, line in enumerate(text.split("\n")):
                y = y0 + k * line_height
                relative_start = y
                if k == 0:
                    ctext = '   Probability      Id         Tag'
                    blank_image = cv2.putText(
                        blank_image, ctext, (x, y), font, 0.8, (66, 245,173),2, lineType)
                else:
                    blank_image = cv2.putText(
                        blank_image, line[3:], (x, y), font, 0.8, (66, 245,173),2, lineType)


        wrapped_text = textwrap.wrap(jo, width=50)
        x, y0 = (10, relative_start)
        if relative_start > 700:
            y = relative_start
        else:
            y = 700
        
        for p, line in enumerate(wrapped_text):
            print(line)
            y = y + 30
            blank_image =  cv2.putText(blank_image, line, (10, y), font, 0.7, (66, 245,173),2, lineType)





        frames_stats.append(blank_image)


        last = None

        if len(tagsData[i]) == 0:
            pass

        elif not isCompliant(tagsData[i]): # this checks for compliance for the frame
            if i % 5 == 0:
                PrintNonCompliance(frames, i, font, lineType) # this prints non-compliant labels
                last = 0
            else:
                if last == None:
                    PrintNonCompliance(frames, i, font, lineType)
                    last = 0
                else:
                    printCNC(last, frames, font, lineType) # this checks for compliance before applying compliance labels

        else:
            if i % 5 == 0:
                PrintCompliance(frames, i, font, lineType) # this prints compliant labels
                last = 1
            else:
                if last == None:
                    PrintCompliance(frames, i, font, lineType)
                    last = 1
                else:
                    printCNC(last, frames, font, lineType)



        for j,single in enumerate(coods_single):
            # This puts the tab on top of the detected item
            tagSize = cv2.getTextSize(tagsData[i][j], font, 0.9, 2)
            frames[i] = cv2.rectangle(frames[i],  (int(single['left']) - 3, int(single['top']) - 30), ((int(single['left']) + tagSize[0][0] + 5, int(single['top']) - 3)), (66, 245,173), -1)
            
            frames[i] = cv2.putText(frames[i],tagsData[i][j],
                (int(single['left'] + 2), int(single['top']) + - 8),
                font,
                0.9,
                (0,0,0),2,
                lineType)

            # This creates the bounding box
            frames[i] = cv2.rectangle(frames[i],  (int(single['left']), int(single['top'])), (int(single['left'])+int(single['width']), int(single['top'])+int(single['height'])), (66, 245,173) ,3)

        
        frames[i] = np.concatenate((frames[i], frames_stats[i]), axis=1)

    SaveVideo(frames, output_file_name) # this converts the processed frames into a video
    stats_path = output_file_name.replace('Output', 'Stats')
    SaveVideo(frames_stats, stats_path)

# %% [markdown]
# ## Video conversion and ADLSGen2 Storage
#
# We will make function calls to convert the raw input video to processed video and store the processed video to ADLSGen2 storage.

# %%
# creating Output and Stats directories for saving processed videos 
if not os.path.isdir("Output"):
   os.mkdir("Output")
if not os.path.isdir("Stats"):
   os.mkdir("Stats")

# %%
# converting raw input video to processed video complete with tags and stats
threshold=0.9
nframes="all"
ConvertVideo(input_video_path, output_video_path,threshold, nframes)
# Out:
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# Multiplying by 1920 , 1080
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9048108, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.90862143, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.903491855, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.909927845, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.91364, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.917198539, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9186192, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.910308659, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.918810248, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9104722, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9167933, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9118618, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9045715, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.916216, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9176328, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.912451863, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9346667, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 10    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.930104554, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9371949, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.942053258, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.945819855, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.950784445, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9450988, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9461739, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9497872, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.941787958, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.942791045, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.941642, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.950936, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9489971, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.937986851, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.943226, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.940732, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9396805, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9479491, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9564096, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.952362061, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.948542356, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.944816053, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9460008, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.947443247, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9433479, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9479303, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9514018, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.94548595, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.952053666, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.947871149, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9486359, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.944173634, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9462243, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.945529461, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9448849, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.941975355, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9388831, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.931184, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.917216957, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.950091958, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.938888431, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9441954, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9435993, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9510772, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.947971046, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.958257556, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9482198, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9438885, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.938856542, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9422513, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.952669144, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9401489, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.947896838, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9507275, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9515294, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9478139, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9363481, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9123011, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.904164135, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.91813904, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.954877734, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 21    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9218961, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.927025855, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 14    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9252786, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9097875, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.917038, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 12    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9474191, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.96803, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9392275, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.94293195, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9436471, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 16    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9090652, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# 13    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9214038, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9338449, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9419135, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.94821924, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 12    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.940669, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.938483834, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9514857, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.950639, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 13    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.915149748, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 14    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9401297, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9521535, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 14    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.928457141, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 12    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9130806, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 12    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9131201, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.910081863, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 10    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9362319, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.94620657, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# 14    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9285974, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 15    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9378001, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 12    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9411661, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 13    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9452445, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# 10    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9222566, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.917805, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9449122, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9445705, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# 13    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.904969156, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# 12    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9487521, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9288119, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 10    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.922915637, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9350699, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# Series([], Name: tagId, dtype: object)
# []
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.925342739, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9151349, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9618961, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.94414705, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.96242404, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.905772448, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# Series([], Name: tagId, dtype: object)
# []
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9617285, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.976188362, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 12    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.966211259, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 10    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.977910757, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 10    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.960135162, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9517642, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.972489059, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 12    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9494612, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9690562, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9799987, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 13    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.977537632, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 12    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9691724, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 10    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.97240746, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.980791032, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 13    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.957994044, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 14    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9649135, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.958119869, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.955432951, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9668342, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 15    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9848715, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9861908, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 13    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9888297, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9864611, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9827369, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.966115057, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9883458, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9927777, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 15    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9896242, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 13    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.995187759, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9953071, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9951345, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9903675, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.988981545, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9926999, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.991961956, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.992714763, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.996283054, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.997415543, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 10    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.996290147, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9950037, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9940133, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9936332, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.994929, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9926356, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.995197833, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.997254968, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9967824, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9967331, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.997610033, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 13    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9974881, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9973126, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9969533, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.996903062, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9966879, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.99791497, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.997805059, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9979688, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 10    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.997322559, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.995782554, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9955863, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 11    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9967267, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 8    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.997250438, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.996346235, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9963177, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9958436, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9957723, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 6    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9963011, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9959147, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9948931, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 7    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9959115, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.994389355, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 9    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# ...
# 0.9844065, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998637736, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.984750152, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 1    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998616934, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.9854685, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 1    1b37ce45-4511-41d2-a330-54abd6647fbf
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9986159, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9810369, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 1    1b37ce45-4511-41d2-a330-54abd6647fbf
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998396456, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.984397531, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 2    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9984343, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.983552933, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 2    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9982358, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.98265624, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 2    1b37ce45-4511-41d2-a330-54abd6647fbf
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9981808, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.981707454, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9981647, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9824399, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9983367, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9825542, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9984994, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9805698, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.99851954, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.9798597, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998498, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9802456, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9984391, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.98039633, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9985369, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.980854332, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9985287, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9796353, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9985465, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9821362, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998476148, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.980304956, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998510361, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.979563355, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998487532, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.9782837, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 2    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9985451, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9788999, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 2    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998603642, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.983198, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9987309, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9796813, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.99873513, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.9808592, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9986177, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9816702, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998707, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.978369832, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9986101, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.978704631, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9985533, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.981443942, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9985335, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.978931367, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9985387, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.979050159, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9986013, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9779357, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9984465, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.981425643, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 1    1b37ce45-4511-41d2-a330-54abd6647fbf
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998528242, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.9835376, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998712242, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.9834598, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 1    1b37ce45-4511-41d2-a330-54abd6647fbf
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.99882, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.983415663, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9987846, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.984139264, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 1    1b37ce45-4511-41d2-a330-54abd6647fbf
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9987503, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9851164, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 2    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998579562, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.986208558, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9986501, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9828, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 1    1b37ce45-4511-41d2-a330-54abd6647fbf
# 2    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9986704, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9813596, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998494446, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.982287645, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9982331, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9795994, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9978975, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9761032, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9967094, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.979315758, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 1    1b37ce45-4511-41d2-a330-54abd6647fbf
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9967013, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9824292, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.997728348, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.9839411, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.997208, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.983250141, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 1    1b37ce45-4511-41d2-a330-54abd6647fbf
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9975169, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.97827, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 1    1b37ce45-4511-41d2-a330-54abd6647fbf
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9974348, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.978624642, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 2    1b37ce45-4511-41d2-a330-54abd6647fbf
# 5    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.997793, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.982492566, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 1    1b37ce45-4511-41d2-a330-54abd6647fbf
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9979753, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.977548, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 1    1b37ce45-4511-41d2-a330-54abd6647fbf
# 4    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998480558, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.9810783, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 2    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998406053, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.9728356, "tagId": "db8815b8a3",
# "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 2    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9986281, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.963605762, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9984252, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.963610768, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 3    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9984332, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.962999642, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 2    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.998220563, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.962503135, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 1    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9981036, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9742649, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 2    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.9980391, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9783501, "tagId": "db8815b8a3", "tagName":
# "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 2    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.997481763, "tagId":
# "db8815b8a3", "tagName": "welding_helmet"},
# {"probability": 0.974592149, "tagId":
# "db8815b8a3", "tagName": "worker"}]
# 0    1b37ce45-4511-41d2-a330-54abd6647fbf
# 2    472acff5-1d3f-44db-9688-45db8815b8a3
# Name: tagId, dtype: object
# [{"probability": 0.997941, "tagId": "db8815b8a3",
# "tagName": "welding_helmet"}, {"probability":
# 0.9783124, "tagId": "db8815b8a3", "tagName":
# "worker"}]

# %%
# %%capture

# uploading the processed video to the Output directory in the ADLSGen2 storage container
output_blob_file= output_folder + output_file
blob_service.create_blob_from_path(STORAGE_CONTAINER_NAME,output_blob_file ,output_video_path)

# %% [markdown]
# ## Displaying frames from processed video

# %%
# saving processed video as images inside the frames directory
images = []
byteImages = []
vidObj = cv2.VideoCapture(output_video_path)
count = 0
success = 1
currentDir = os.getcwd()
if not os.path.isdir("frames"):
   os.mkdir("frames")
while success:
      success, image = vidObj.read()
      if success:
          cv2.imwrite("frames/frame%d.jpg" % count, image) 
          count += 1

images_num=(len(fnmatch.filter(os.listdir(os.getcwd() + "/frames"), '*.jpg')))

# displaying images from frames directory
i=0
for i in range(images_num):
    if i%75==0:
      a = plt.imread("frames/frame%d.jpg" % i)
      plt.imshow(a)
      plt.show()
