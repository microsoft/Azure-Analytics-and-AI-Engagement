# %% [markdown]
# ### Mount ADLS Gen 2 to Azure Databricks (Source)

# %%
source_mount_point ="abfss://data-source@#STORAGE_ACCOUNT_NAME#.dfs.core.windows.net/"
dest_mount_point = "abfss://delta-files@#STORAGE_ACCOUNT_NAME#.dfs.core.windows.net/"
configs = {"fs.azure.account.auth.type": "OAuth",
          "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
          "fs.azure.account.oauth2.client.id": "#APP_ID#",
          "fs.azure.account.oauth2.client.secret": "#APP_SECRET#",
          "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/#TENANT_ID#/oauth2/token"}

# %%
if not any(mount.mountPoint == "/mnt/data-source" for mount in dbutils.fs.mounts()):
    dbutils.fs.mount(
      source = source_mount_point,
      mount_point = "/mnt/data-source",
      extra_configs = configs)
else:
    print("Mount point already exists.")
    
#     extra_configs = {"fs.azure.account.key.storage84tjho0.dfs.core.windows.net":""}

# %% [markdown]
# ### List directories of Mounted Location to load source data

# %%
# %fs
ls /mnt/data-source
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/data-source/Campaign Data/</td><td>Campaign Data/</td><td>0</td><td>1668597045000</td></tr><tr><td>dbfs:/mnt/data-source/Customer Churn Data/</td><td>Customer Churn Data/</td><td>0</td><td>1668597076000</td></tr><tr><td>dbfs:/mnt/data-source/Sales Data/</td><td>Sales Data/</td><td>0</td><td>1668597027000</td></tr><tr><td>dbfs:/mnt/data-source/Store Transactions Data/</td><td>Store Transactions Data/</td><td>0</td><td>1668597067000</td></tr><tr><td>dbfs:/mnt/data-source/TwitterDataJson/</td><td>TwitterDataJson/</td><td>0</td><td>1668597031000</td></tr><tr><td>dbfs:/mnt/data-source/TwitterDataJsonSource/</td><td>TwitterDataJsonSource/</td><td>0</td><td>1668597026000</td></tr><tr><td>dbfs:/mnt/data-source/TwitterSentiment/</td><td>TwitterSentiment/</td><td>0</td><td>1668597089000</td></tr></tbody></table></div>

# %% [markdown]
# ### Mount ADLS Gen 2 to Azure Databricks (Destination)

# %%
if not any(mount.mountPoint == "/mnt/delta-files" for mount in dbutils.fs.mounts()):
    dbutils.fs.mount(
      source = dest_mount_point,
      mount_point = "/mnt/delta-files",
      extra_configs = configs)
else:
    print("Mount point already exists.")

# %% [markdown]
# ### List directories of Mounted Location to load curated data

# %%
# %fs
ls /mnt/delta-files
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/delta-files/CustomerChurn Data/</td><td>CustomerChurn Data/</td><td>0</td><td>1668597154000</td></tr><tr><td>dbfs:/mnt/delta-files/Data/</td><td>Data/</td><td>0</td><td>1668597164000</td></tr><tr><td>dbfs:/mnt/delta-files/SalesForecast Data/</td><td>SalesForecast Data/</td><td>0</td><td>1668597155000</td></tr><tr><td>dbfs:/mnt/delta-files/dlt/</td><td>dlt/</td><td>0</td><td>1668597154000</td></tr></tbody></table></div>
