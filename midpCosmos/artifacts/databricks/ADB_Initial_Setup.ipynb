# %% [markdown]
# ### Mount ADLS Gen 2 to Azure Databricks (Source)

# %%
source_mount_point ="abfss://data-source@#STORAGE_ACCOUNT_NAME#.dfs.core.windows.net/"
dest_mount_point = "abfss://delta-files@#STORAGE_ACCOUNT_NAME#.dfs.core.windows.net/"

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": "#APP_ID#",
#            "fs.azure.account.oauth2.client.secret": "md08Q~A_ZYpCG4X56rJ5sudIV8AALfYl_Vs4QbNo",
           "fs.azure.account.oauth2.client.secret": "#APP_SECRET#",
           "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/#TENANT_ID#/oauth2/token"}

# %%
dbutils.fs.mounts()
# Out:
# Out[6]: [MountInfo(mountPoint='/databricks-datasets', source='databricks-datasets', encryptionType=''),
#  MountInfo(mountPoint='/databricks/mlflow-tracking', source='databricks/mlflow-tracking', encryptionType=''),
#  MountInfo(mountPoint='/databricks-results', source='databricks-results', encryptionType=''),
#  MountInfo(mountPoint='/databricks/mlflow-registry', source='databricks/mlflow-registry', encryptionType=''),
#  MountInfo(mountPoint='/', source='DatabricksRoot', encryptionType='')]

# %%
# dbutils.fs.unmount('/mnt/data-source')
dbutils.fs.unmount('/mnt/delta-files')
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-2734317015726188>:2
#       1 dbutils.fs.unmount('/mnt/data-source')
# ----> 2 # dbutils.fs.unmount('/mnt/delta-files')
#
# File /databricks/python_shell/dbruntime/dbutils.py:362, in DBUtils.FSHandler.prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#     360 exc.__context__ = None
#     361 exc.__cause__ = None
# --> 362 raise exc
#
# ExecutionError: An error occurred while calling o384.unmount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory not mounted: /mnt/delta-files; nested exception is:
# 	java.lang.IllegalArgumentException: requirement failed: Directory not mounted: /mnt/delta-files
# 	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:135)
# ...

# %%
if not any(mount.mountPoint == "/mnt/data-source" for mount in dbutils.fs.mounts()):
    dbutils.fs.mount(
      source = source_mount_point,
      mount_point = "/mnt/data-source",
      extra_configs = configs)
else:
    print("Mount point already exists.")

# %% [markdown]
# ### List directories of Mounted Location to load source data

# %%
# %fs
ls /mnt/delta-files
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">	at shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.services.AbfsRestOperation.executeHttpOperation(AbfsRestOperation.java:338)
# 	at shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.services.AbfsRestOperation.completeExecute(AbfsRestOperation.java:267)
# ...

# %%
# %fs
ls /mnt/data-source
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ### Mount ADLS Gen 2 to Azure Databricks (Destination)

# %%
if not any(mount.mountPoint == "/mnt/delta-files" for mount in dbutils.fs.mounts()):
    dbutils.fs.mount(
      source = dest_mount_point,
      mount_point = "/mnt/delta-files",
      extra_configs = configs)
else:
    print("Mount point already exists.")

# %% [markdown]
# ### List directories of Mounted Location to load curated data

# %%
# %fs
ls /mnt/delta-files
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
