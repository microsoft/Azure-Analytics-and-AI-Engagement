# %%
df = spark.read.parquet("Files/MCFS-Azure-Data/emissions_0_e535a7fe5690460ab68392ab8eb2f358.parquet")
# df now is a Spark DataFrame containing parquet data from "Files/MCFS-Azure-Data/
#emissions_0_e535a7fe5690460ab68392ab8eb2f358.parquet".
display(df)
# Out:
# StatementMeta(, 5882b1b3-dfce-458d-b1eb-626523e8a522, 6, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 34f89b17-7d88-4314-9fe8-7c44f7994563)
